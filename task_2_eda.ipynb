# %%
# ==============================
# Exploratory Data Analysis for MQTT IDS Dataset (Batch Mode, 3 feature levels)
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import tempfile
import glob

# ------------------------------
# 1. Define file structure
# ------------------------------
base_path = "./"   # Folder where this script is stored

folders = {
    "packet": "packet_features",
    "uniflow": "uniflow_features",
    "biflow": "biflow_features"
}

files = {
    "normal": "normal.csv",
    "sparta": "sparta.csv",
    "scan_A": "scan_A.csv",
    "mqtt_bruteforce": "mqtt_bruteforce.csv",
    "scan_sU": "scan_sU.csv"
}

def build_filenames(prefix):
    return {
        "normal": f"{prefix}_normal.csv",
        "sparta": f"{prefix}_sparta.csv",
        "scan_A": f"{prefix}_scan_A.csv",
        "mqtt_bruteforce": f"{prefix}_mqtt_bruteforce.csv",
        "scan_sU": f"{prefix}_scan_sU.csv"
    }

feature_files = {
    "packet": files,
    "uniflow": build_filenames("uniflow"),
    "biflow": build_filenames("biflow")
}

# ------------------------------
# 2. Create output folder
# ------------------------------
OUTPUT_DIR = "outputs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ------------------------------
# 3. EDA Function (save plots/statistics)
# ------------------------------
def run_batch_eda(data, level, batch_id, filename):
    """Run EDA on a single batch and save plots/stats."""
    batch_tag = f"{level}_{os.path.splitext(os.path.basename(filename))[0]}_batch{batch_id}"

    # Save stats
    stats_file = os.path.join(OUTPUT_DIR, f"{batch_tag}_stats.txt")
    with open(stats_file, "w") as f:
        f.write(f"=== Summary Statistics for {batch_tag} ===\n\n")
        f.write(str(data.describe(include="all")))
        f.write("\n\nClass distribution:\n")
        f.write(str(data["label"].value_counts()))

    # Univariate: length-like columns
    length_cols = [c for c in data.columns if "length" in c.lower()]
    for col in length_cols:
        plt.figure(figsize=(8,5))
        sns.histplot(data, x=col, hue="label", bins=50, kde=True)
        plt.title(f"{batch_tag} | {col} Distribution")
        plt.savefig(os.path.join(OUTPUT_DIR, f"{batch_tag}_{col}_hist.png"))
        plt.close()

    # Flags distribution
    if "flags" in data.columns:
        plt.figure(figsize=(8,5))
        sns.countplot(data=data, x="flags", hue="label")
        plt.title(f"{batch_tag} | Flags Distribution")
        plt.xticks(rotation=45)
        plt.savefig(os.path.join(OUTPUT_DIR, f"{batch_tag}_flags.png"))
        plt.close()

    # Correlation heatmap
    numeric_cols = data.select_dtypes(include=[np.number]).columns
    if len(numeric_cols) > 1:
        plt.figure(figsize=(12,8))
        sns.heatmap(data[numeric_cols].corr(), cmap="coolwarm", center=0)
        plt.title(f"{batch_tag} | Correlation Heatmap")
        plt.savefig(os.path.join(OUTPUT_DIR, f"{batch_tag}_corr.png"))
        plt.close()

    # Class balance
    plt.figure(figsize=(6,4))
    sns.countplot(data=data, x="label")
    plt.title(f"{batch_tag} | Class Distribution")
    plt.savefig(os.path.join(OUTPUT_DIR, f"{batch_tag}_classdist.png"))
    plt.close()

    print(f"[SAVED] EDA outputs for {batch_tag}")

# ------------------------------
# 4. Batch Loader with EDA
# ------------------------------
def load_and_process_in_batches(filepath, label, level, chunksize=200000):
    """Load large CSV in chunks, add label, run EDA per batch."""
    for i, chunk in enumerate(pd.read_csv(filepath, chunksize=chunksize, low_memory=False)):
        chunk["label"] = label
        run_batch_eda(chunk, level, i+1, filepath)

# ------------------------------
# 5. Run across all datasets
# ------------------------------
for level, file_dict in feature_files.items():
    folder_path = os.path.join(base_path, folders[level])
    for name, fname in file_dict.items():
        fpath = os.path.join(folder_path, fname)
        label = 0 if name == "normal" else 1
        print(f"\n[INFO] Processing {fpath} ...")
        load_and_process_in_batches(fpath, label, level)

# ------------------------------
# 6. Cleanup Intermediate Files
# ------------------------------
# Delete any leftover temporary files created during processing
tmp_dirs = [tempfile.gettempdir(), base_path]
for d in tmp_dirs:
    for f in glob.glob(os.path.join(d, "*.tmp")) + glob.glob(os.path.join(d, "*.temp")):
        try:
            os.remove(f)
            print(f"[CLEANUP] Removed temp file: {f}")
        except Exception as e:
            print(f"[CLEANUP] Could not remove {f}: {e}")

print("\n[SUCCESS] All batch-wise EDA completed. Outputs saved in 'outputs/' folder.")
print("[CLEANUP] Temporary files removed.")
# Out:
# [INFO] Processing ./packet_features\normal.csv ...
# [SAVED] EDA outputs for packet_normal_batch1
# [SAVED] EDA outputs for packet_normal_batch2
# [SAVED] EDA outputs for packet_normal_batch3
# [SAVED] EDA outputs for packet_normal_batch4
# [SAVED] EDA outputs for packet_normal_batch5
# [SAVED] EDA outputs for packet_normal_batch6
#
# [INFO] Processing ./packet_features\sparta.csv ...
# [SAVED] EDA outputs for packet_sparta_batch1
# [SAVED] EDA outputs for packet_sparta_batch2
# [SAVED] EDA outputs for packet_sparta_batch3
# [SAVED] EDA outputs for packet_sparta_batch4
# [SAVED] EDA outputs for packet_sparta_batch5
# [SAVED] EDA outputs for packet_sparta_batch6
# [SAVED] EDA outputs for packet_sparta_batch7
# [SAVED] EDA outputs for packet_sparta_batch8
# [SAVED] EDA outputs for packet_sparta_batch9
# [SAVED] EDA outputs for packet_sparta_batch10
# [SAVED] EDA outputs for packet_sparta_batch11
# [SAVED] EDA outputs for packet_sparta_batch12
# [SAVED] EDA outputs for packet_sparta_batch13
# [SAVED] EDA outputs for packet_sparta_batch14
# [SAVED] EDA outputs for packet_sparta_batch15
# [SAVED] EDA outputs for packet_sparta_batch16
# [SAVED] EDA outputs for packet_sparta_batch17
# [SAVED] EDA outputs for packet_sparta_batch18
# [SAVED] EDA outputs for packet_sparta_batch19
# [SAVED] EDA outputs for packet_sparta_batch20
# [SAVED] EDA outputs for packet_sparta_batch21
# [SAVED] EDA outputs for packet_sparta_batch22
# [SAVED] EDA outputs for packet_sparta_batch23
# [SAVED] EDA outputs for packet_sparta_batch24
# [SAVED] EDA outputs for packet_sparta_batch25
# [SAVED] EDA outputs for packet_sparta_batch26
# [SAVED] EDA outputs for packet_sparta_batch27
# [SAVED] EDA outputs for packet_sparta_batch28
# [SAVED] EDA outputs for packet_sparta_batch29
# [SAVED] EDA outputs for packet_sparta_batch30
# [SAVED] EDA outputs for packet_sparta_batch31
# [SAVED] EDA outputs for packet_sparta_batch32
# [SAVED] EDA outputs for packet_sparta_batch33
# [SAVED] EDA outputs for packet_sparta_batch34
# [SAVED] EDA outputs for packet_sparta_batch35
# [SAVED] EDA outputs for packet_sparta_batch36
# [SAVED] EDA outputs for packet_sparta_batch37
# [SAVED] EDA outputs for packet_sparta_batch38
# [SAVED] EDA outputs for packet_sparta_batch39
# [SAVED] EDA outputs for packet_sparta_batch40
# [SAVED] EDA outputs for packet_sparta_batch41
# [SAVED] EDA outputs for packet_sparta_batch42
# [SAVED] EDA outputs for packet_sparta_batch43
# [SAVED] EDA outputs for packet_sparta_batch44
# [SAVED] EDA outputs for packet_sparta_batch45
# [SAVED] EDA outputs for packet_sparta_batch46
# [SAVED] EDA outputs for packet_sparta_batch47
# [SAVED] EDA outputs for packet_sparta_batch48
# [SAVED] EDA outputs for packet_sparta_batch49
# [SAVED] EDA outputs for packet_sparta_batch50
# [SAVED] EDA outputs for packet_sparta_batch51
# [SAVED] EDA outputs for packet_sparta_batch52
# [SAVED] EDA outputs for packet_sparta_batch53
# [SAVED] EDA outputs for packet_sparta_batch54
# [SAVED] EDA outputs for packet_sparta_batch55
# [SAVED] EDA outputs for packet_sparta_batch56
# [SAVED] EDA outputs for packet_sparta_batch57
# [SAVED] EDA outputs for packet_sparta_batch58
# [SAVED] EDA outputs for packet_sparta_batch59
# [SAVED] EDA outputs for packet_sparta_batch60
# [SAVED] EDA outputs for packet_sparta_batch61
# [SAVED] EDA outputs for packet_sparta_batch62
# [SAVED] EDA outputs for packet_sparta_batch63
# [SAVED] EDA outputs for packet_sparta_batch64
# [SAVED] EDA outputs for packet_sparta_batch65
# [SAVED] EDA outputs for packet_sparta_batch66
# [SAVED] EDA outputs for packet_sparta_batch67
# [SAVED] EDA outputs for packet_sparta_batch68
# [SAVED] EDA outputs for packet_sparta_batch69
# [SAVED] EDA outputs for packet_sparta_batch70
# [SAVED] EDA outputs for packet_sparta_batch71
# [SAVED] EDA outputs for packet_sparta_batch72
# [SAVED] EDA outputs for packet_sparta_batch73
# [SAVED] EDA outputs for packet_sparta_batch74
# [SAVED] EDA outputs for packet_sparta_batch75
# [SAVED] EDA outputs for packet_sparta_batch76
# [SAVED] EDA outputs for packet_sparta_batch77
# [SAVED] EDA outputs for packet_sparta_batch78
# [SAVED] EDA outputs for packet_sparta_batch79
# [SAVED] EDA outputs for packet_sparta_batch80
# [SAVED] EDA outputs for packet_sparta_batch81
# [SAVED] EDA outputs for packet_sparta_batch82
# [SAVED] EDA outputs for packet_sparta_batch83
# [SAVED] EDA outputs for packet_sparta_batch84
# [SAVED] EDA outputs for packet_sparta_batch85
# [SAVED] EDA outputs for packet_sparta_batch86
# [SAVED] EDA outputs for packet_sparta_batch87
# [SAVED] EDA outputs for packet_sparta_batch88
# [SAVED] EDA outputs for packet_sparta_batch89
# [SAVED] EDA outputs for packet_sparta_batch90
# [SAVED] EDA outputs for packet_sparta_batch91
# [SAVED] EDA outputs for packet_sparta_batch92
# [SAVED] EDA outputs for packet_sparta_batch93
# [SAVED] EDA outputs for packet_sparta_batch94
# [SAVED] EDA outputs for packet_sparta_batch95
# [SAVED] EDA outputs for packet_sparta_batch96
# [SAVED] EDA outputs for packet_sparta_batch97
# [SAVED] EDA outputs for packet_sparta_batch98
# [SAVED] EDA outputs for packet_sparta_batch99
# [SAVED] EDA outputs for packet_sparta_batch100
# [SAVED] EDA outputs for packet_sparta_batch101
# [SAVED] EDA outputs for packet_sparta_batch102
# [SAVED] EDA outputs for packet_sparta_batch103
# [SAVED] EDA outputs for packet_sparta_batch104
#
# [INFO] Processing ./packet_features\scan_A.csv ...
# [SAVED] EDA outputs for packet_scan_A_batch1
#
# [INFO] Processing ./packet_features\mqtt_bruteforce.csv ...
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch1
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch2
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch3
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch4
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch5
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch6
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch7
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch8
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch9
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch10
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch11
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch12
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch13
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch14
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch15
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch16
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch17
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch18
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch19
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch20
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch21
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch22
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch23
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch24
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch25
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch26
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch27
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch28
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch29
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch30
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch31
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch32
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch33
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch34
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch35
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch36
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch37
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch38
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch39
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch40
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch41
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch42
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch43
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch44
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch45
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch46
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch47
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch48
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch49
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch50
# [SAVED] EDA outputs for packet_mqtt_bruteforce_batch51
#
# [INFO] Processing ./packet_features\scan_sU.csv ...
# [SAVED] EDA outputs for packet_scan_sU_batch1
# [SAVED] EDA outputs for packet_scan_sU_batch2
#
# [INFO] Processing ./uniflow_features\uniflow_normal.csv ...
# [SAVED] EDA outputs for uniflow_uniflow_normal_batch1
#
# [INFO] Processing ./uniflow_features\uniflow_sparta.csv ...
# [SAVED] EDA outputs for uniflow_uniflow_sparta_batch1
#
# [INFO] Processing ./uniflow_features\uniflow_scan_A.csv ...
# [SAVED] EDA outputs for uniflow_uniflow_scan_A_batch1
#
# [INFO] Processing ./uniflow_features\uniflow_mqtt_bruteforce.csv ...
# [SAVED] EDA outputs for uniflow_uniflow_mqtt_bruteforce_batch1
#
# [INFO] Processing ./uniflow_features\uniflow_scan_sU.csv ...
# [SAVED] EDA outputs for uniflow_uniflow_scan_sU_batch1
#
# [INFO] Processing ./biflow_features\biflow_normal.csv ...
# [SAVED] EDA outputs for biflow_biflow_normal_batch1
#
# [INFO] Processing ./biflow_features\biflow_sparta.csv ...
# [SAVED] EDA outputs for biflow_biflow_sparta_batch1
#
# [INFO] Processing ./biflow_features\biflow_scan_A.csv ...
# [SAVED] EDA outputs for biflow_biflow_scan_A_batch1
#
# [INFO] Processing ./biflow_features\biflow_mqtt_bruteforce.csv ...
# [SAVED] EDA outputs for biflow_biflow_mqtt_bruteforce_batch1
#
# [INFO] Processing ./biflow_features\biflow_scan_sU.csv ...
# [SAVED] EDA outputs for biflow_biflow_scan_sU_batch1
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\0e17a60b-353b-41b7-aa59-fc0e6960849d.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\0e17a60b-353b-41b7-aa59-fc0e6960849d.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\0eab35e0-cfb4-48a4-8be1-3348cf9358b0.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\0eab35e0-cfb4-48a4-8be1-3348cf9358b0.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\30a0848c-aaba-44b3-a147-ea6efe5d502c.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\30a0848c-aaba-44b3-a147-ea6efe5d502c.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\35d05f41-63d8-4529-909e-d0d9d09b39ed.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\35d05f41-63d8-4529-909e-d0d9d09b39ed.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\4179e4f9-3d67-4d63-abfd-da9f59b6d58b.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\4179e4f9-3d67-4d63-abfd-da9f59b6d58b.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\57fc87e6-2232-41a9-adc9-fb84eae4582c.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\57fc87e6-2232-41a9-adc9-fb84eae4582c.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\585e16ec-e62f-496f-af14-9e80f11f8baa.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\585e16ec-e62f-496f-af14-9e80f11f8baa.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\5afee226-99d3-4b6e-8b9b-8c4f83e32818.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\5afee226-99d3-4b6e-8b9b-8c4f83e32818.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\7a2d7f6f-f5ba-4e67-a571-b7edb75c8613.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\7a2d7f6f-f5ba-4e67-a571-b7edb75c8613.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\89a78ade-5dbf-495c-a5d4-fb757dc5faec.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\89a78ade-5dbf-495c-a5d4-fb757dc5faec.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\94f68c5c-0a83-4166-9cc8-b59e2d581043.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\94f68c5c-0a83-4166-9cc8-b59e2d581043.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\a51780c7-8acd-48d6-aca3-01fefc1289e9.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\a51780c7-8acd-48d6-aca3-01fefc1289e9.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\c43eb39d-9168-4f03-9c32-0c0f2ae4d1bd.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\c43eb39d-9168-4f03-9c32-0c0f2ae4d1bd.tmp'
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\CFG1244.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\CFGF35.tmp
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\d18e992f-6dc1-42b3-b672-29414e57390e.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\d18e992f-6dc1-42b3-b672-29414e57390e.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\d457aff5-f21e-46ce-81a1-1157c187cc15.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\d457aff5-f21e-46ce-81a1-1157c187cc15.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\f98e347a-d57a-46ee-8a10-941e60e1a804.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\f98e347a-d57a-46ee-8a10-941e60e1a804.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\fb49bc43-d9ae-456f-a1db-dce4f4270d35.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\fb49bc43-d9ae-456f-a1db-dce4f4270d35.tmp'
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct1993.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct1D5D.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct2733.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct359.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct40B3.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct4597.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct478C.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct4C9D.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct4FEA.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct5E14.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct63D4.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct699B.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct6FAC.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct7334.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct73AE.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct7410.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct76FB.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct7CF1.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct849F.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct8AE5.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct8CEC.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct93E8.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct9ABF.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct9DCB.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wct9E1C.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctB205.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctB2ED.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctB9EF.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctBD9F.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctC1E0.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctCA9D.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctCB52.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctCF54.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctD926.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctE3D7.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctE93.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctEEF7.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\wctF272.tmp
# [CLEANUP] Removed temp file: C:\Users\VALMIK~1\AppData\Local\Temp\zm_upgrade_record.tmp
#
# [SUCCESS] All batch-wise EDA completed. Outputs saved in 'outputs/' folder.
# [CLEANUP] Temporary files removed.
