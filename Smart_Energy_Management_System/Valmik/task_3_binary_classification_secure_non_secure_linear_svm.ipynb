# %%
# mqtt_ids_svm_train.py
# Batch + epoch training of a nonlinear soft-margin SVM (via SGD hinge loss approximation)
# for binary classification: secure (False) vs under attack (True).
#
# Dataset files are read in chunks to support large data.
# The target column "attack" is True if under attack, False if secure.
# Validation and test pools are sampled and stored in-memory.
# Cleanup removes intermediate files created during preprocessing.

import os
import glob
import time
import tempfile
import numpy as np
import pandas as pd
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
import random

# ------------------------------
# Config
# ------------------------------
base_path = "./"

folders = {
    "packet": "packet_features",
    "uniflow": "uniflow_features",
    "biflow": "biflow_features"
}

files = {
    "normal": "normal.csv",
    "sparta": "sparta.csv",
    "scan_A": "scan_A.csv",
    "mqtt_bruteforce": "mqtt_bruteforce.csv",
    "scan_sU": "scan_sU.csv"
}

def build_filenames(prefix):
    return {
        "normal": f"{prefix}_normal.csv",
        "sparta": f"{prefix}_sparta.csv",
        "scan_A": f"{prefix}_scan_A.csv",
        "mqtt_bruteforce": f"{prefix}_mqtt_bruteforce.csv",
        "scan_sU": f"{prefix}_scan_sU.csv"
    }

feature_files = {
    "packet": files,
    "uniflow": build_filenames("uniflow"),
    "biflow": build_filenames("biflow")
}

CHUNKSIZE = 200000
TRAIN_FRACTION = 0.80
VAL_FRACTION = 0.10
TEST_FRACTION = 0.10

EPOCHS = 3
SAMPLE_VAL_MAX = 20000
SAMPLE_TEST_MAX = 20000

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

# ------------------------------
# Cleanup helpers
# ------------------------------
def safe_remove(path):
    try:
        if os.path.exists(path):
            os.remove(path)
            print(f"[CLEANUP] Removed file: {path}")
    except Exception as e:
        print(f"[CLEANUP] Could not remove {path}: {e}")

# ------------------------------
# Data streaming
# ------------------------------
def stream_chunks(feature_files_map, base_path, chunksize=CHUNKSIZE):
    """Yield (level, file_key, filepath, chunk_df)."""
    for level, file_dict in feature_files_map.items():
        folder_path = os.path.join(base_path, folders[level])
        for key, fname in file_dict.items():
            fpath = os.path.join(folder_path, fname)
            if not os.path.isfile(fpath):
                print(f"[WARN] Missing: {fpath}")
                continue
            try:
                for chunk in pd.read_csv(fpath, chunksize=chunksize, low_memory=False):
                    yield (level, key, fpath, chunk)
            except Exception as e:
                print(f"[ERROR] Failed to read {fpath}: {e}")

# ------------------------------
# Preprocess chunk
# ------------------------------
def preprocess_chunk(df, file_key, expected_features=None):
    df = df.copy()
    # Boolean target: False = normal, True = attack
    df["attack"] = (file_key != "normal")

    y = df["attack"].astype(int).values
    numeric_df = df.select_dtypes(include=[np.number]).copy()
    numeric_df = numeric_df.drop(columns=[c for c in ["attack", "label"] if c in numeric_df.columns])

    if expected_features is not None:
        # Reindex to master feature set, fill missing with 0
        numeric_df = numeric_df.reindex(columns=expected_features, fill_value=0.0)
        feature_names = expected_features
    else:
        feature_names = list(numeric_df.columns)

    X = numeric_df.fillna(0.0).values.astype(np.float32)
    return X, y, feature_names

# ------------------------------
# Training loop
# ------------------------------
def train_svm_batchwise(feature_files_map, base_path, epochs=EPOCHS):
    scaler = StandardScaler(with_mean=False)  # sparse-friendly
    svm = SGDClassifier(
        loss="hinge",     # SVM hinge loss
        penalty="l2",     # soft-margin
        alpha=0.0001,     # regularization strength
        max_iter=1,
        learning_rate="optimal",
        tol=None,
        warm_start=True
    )

    feature_names_master = None
    val_X, val_y = None, None
    test_X, test_y = None, None
    total_batches = 0

    for epoch in range(1, epochs + 1):
        print(f"\n=== EPOCH {epoch}/{epochs} ===")
        for level, file_key, filepath, chunk in stream_chunks(feature_files_map, base_path):
            total_batches += 1
            tag = f"ep{epoch}_b{total_batches}"
            print(f"[BATCH {tag}] {level}/{file_key} shape={chunk.shape}")

            try:
                if feature_names_master is None:
                    X, y, features = preprocess_chunk(chunk, file_key)
                    feature_names_master = features
                else:
                    X, y, _ = preprocess_chunk(chunk, file_key, expected_features=feature_names_master)
            except Exception as e:
                print(f"[SKIP] {e}")
                continue

            if X.shape[1] == 0:
                print(f"[SKIP] {tag} has 0 features after preprocessing.")
                continue

            n = X.shape[0]
            if n == 0: 
                continue

            rnd = np.random.rand(n)
            train_mask = rnd < TRAIN_FRACTION
            val_mask = (rnd >= TRAIN_FRACTION) & (rnd < TRAIN_FRACTION + VAL_FRACTION)
            test_mask = rnd >= TRAIN_FRACTION + VAL_FRACTION

            X_train, y_train = X[train_mask], y[train_mask]
            X_val, y_val = X[val_mask], y[val_mask]
            X_test, y_test_ = X[test_mask], y[test_mask]

            # Scale + partial fit
            if X_train.shape[0] > 0:
                X_train = scaler.partial_fit(X_train).transform(X_train)
                if not hasattr(svm, "classes_"):
                    svm.partial_fit(X_train, y_train, classes=np.array([0, 1]))
                else:
                    svm.partial_fit(X_train, y_train)
                print(f"[BATCH {tag}] trained on {X_train.shape[0]} rows.")

            # Validation pool
            if X_val.shape[0] > 0:
                X_val = scaler.transform(X_val)
                if val_X is None:
                    take = min(X_val.shape[0], SAMPLE_VAL_MAX)
                    idxs = np.random.choice(X_val.shape[0], take, replace=False)
                    val_X, val_y = X_val[idxs], y_val[idxs]
                else:
                    val_X = np.vstack([val_X, X_val])
                    val_y = np.concatenate([val_y, y_val])
                    if val_X.shape[0] > SAMPLE_VAL_MAX:
                        idxs = np.random.choice(val_X.shape[0], SAMPLE_VAL_MAX, replace=False)
                        val_X, val_y = val_X[idxs], val_y[idxs]

            # Test pool
            if X_test.shape[0] > 0:
                X_test = scaler.transform(X_test)
                if test_X is None:
                    take = min(X_test.shape[0], SAMPLE_TEST_MAX)
                    idxs = np.random.choice(X_test.shape[0], take, replace=False)
                    test_X, test_y = X_test[idxs], y_test_[idxs]
                else:
                    test_X = np.vstack([test_X, X_test])
                    test_y = np.concatenate([test_y, y_test_])
                    if test_X.shape[0] > SAMPLE_TEST_MAX:
                        idxs = np.random.choice(test_X.shape[0], SAMPLE_TEST_MAX, replace=False)
                        test_X, test_y = test_X[idxs], test_y[idxs]

        # Epoch validation
        if val_X is not None and val_X.shape[0] > 0:
            preds = svm.predict(val_X)
            acc = accuracy_score(val_y, preds)
            f1 = f1_score(val_y, preds, average="macro")
            print(f"[EPOCH {epoch}] Val Acc={acc:.4f}  F1={f1:.4f}")

    # Final test
    if test_X is not None and test_X.shape[0] > 0:
        preds = svm.predict(test_X)
        acc = accuracy_score(test_y, preds)
        f1 = f1_score(test_y, preds, average="macro")
        print("\n=== FINAL TEST METRICS ===")
        print(f"Test Acc={acc:.4f}  F1={f1:.4f}")
        print(classification_report(test_y, preds, target_names=["Secure(False)", "Attack(True)"]))
    else:
        print("No test data available.")

    return svm, feature_names_master

# ------------------------------
# Main
# ------------------------------
if __name__ == "__main__":
    start = time.time()
    print("[START] Training nonlinear SVM with batch/epoch approach...")
    try:
        svm, features = train_svm_batchwise(feature_files, base_path, epochs=EPOCHS)
    except Exception as e:
        print(f"[FATAL] Error: {e}")
    elapsed = time.time() - start
    print(f"[DONE] Total time {elapsed:.1f}s")

    # Cleanup temp files
    print("\n[START CLEANUP]")
    tmpdir = tempfile.gettempdir()
    for pattern in ["*.tmp", "*.temp", "tmp*"]:
        for f in glob.glob(os.path.join(tmpdir, pattern)):
            safe_remove(f)
    print("[CLEANUP] Completed.")
# Out:
# [START] Training nonlinear SVM with batch/epoch approach...
#
# === EPOCH 1/3 ===
# [BATCH ep1_b1] packet/normal shape=(200000, 31)
# [BATCH ep1_b1] trained on 159902 rows.
# [BATCH ep1_b2] packet/normal shape=(200000, 31)
# [BATCH ep1_b2] trained on 160096 rows.
# [BATCH ep1_b3] packet/normal shape=(200000, 31)
# [BATCH ep1_b3] trained on 160037 rows.
# [BATCH ep1_b4] packet/normal shape=(200000, 31)
# [BATCH ep1_b4] trained on 160029 rows.
# [BATCH ep1_b5] packet/normal shape=(200000, 31)
# [BATCH ep1_b5] trained on 160198 rows.
# [BATCH ep1_b6] packet/normal shape=(56231, 31)
# [BATCH ep1_b6] trained on 44973 rows.
# [BATCH ep1_b7] packet/sparta shape=(200000, 31)
# [BATCH ep1_b7] trained on 159897 rows.
# [BATCH ep1_b8] packet/sparta shape=(200000, 31)
# [BATCH ep1_b8] trained on 159957 rows.
# [BATCH ep1_b9] packet/sparta shape=(200000, 31)
# [BATCH ep1_b9] trained on 160138 rows.
# [BATCH ep1_b10] packet/sparta shape=(200000, 31)
# [BATCH ep1_b10] trained on 160133 rows.
# [BATCH ep1_b11] packet/sparta shape=(200000, 31)
# [BATCH ep1_b11] trained on 159921 rows.
# [BATCH ep1_b12] packet/sparta shape=(200000, 31)
# [BATCH ep1_b12] trained on 160052 rows.
# [BATCH ep1_b13] packet/sparta shape=(200000, 31)
# [BATCH ep1_b13] trained on 159944 rows.
# [BATCH ep1_b14] packet/sparta shape=(200000, 31)
# [BATCH ep1_b14] trained on 159759 rows.
# [BATCH ep1_b15] packet/sparta shape=(200000, 31)
# [BATCH ep1_b15] trained on 160169 rows.
# [BATCH ep1_b16] packet/sparta shape=(200000, 31)
# [BATCH ep1_b16] trained on 159739 rows.
# [BATCH ep1_b17] packet/sparta shape=(200000, 31)
# [BATCH ep1_b17] trained on 160073 rows.
# [BATCH ep1_b18] packet/sparta shape=(200000, 31)
# [BATCH ep1_b18] trained on 160131 rows.
# [BATCH ep1_b19] packet/sparta shape=(200000, 31)
# [BATCH ep1_b19] trained on 160133 rows.
# [BATCH ep1_b20] packet/sparta shape=(200000, 31)
# [BATCH ep1_b20] trained on 160427 rows.
# [BATCH ep1_b21] packet/sparta shape=(200000, 31)
# [BATCH ep1_b21] trained on 159587 rows.
# [BATCH ep1_b22] packet/sparta shape=(200000, 31)
# [BATCH ep1_b22] trained on 159800 rows.
# [BATCH ep1_b23] packet/sparta shape=(200000, 31)
# [BATCH ep1_b23] trained on 159794 rows.
# [BATCH ep1_b24] packet/sparta shape=(200000, 31)
# [BATCH ep1_b24] trained on 159880 rows.
# [BATCH ep1_b25] packet/sparta shape=(200000, 31)
# [BATCH ep1_b25] trained on 160182 rows.
# [BATCH ep1_b26] packet/sparta shape=(200000, 31)
# [BATCH ep1_b26] trained on 159923 rows.
# [BATCH ep1_b27] packet/sparta shape=(200000, 31)
# [BATCH ep1_b27] trained on 159847 rows.
# [BATCH ep1_b28] packet/sparta shape=(200000, 31)
# [BATCH ep1_b28] trained on 160028 rows.
# [BATCH ep1_b29] packet/sparta shape=(200000, 31)
# [BATCH ep1_b29] trained on 160170 rows.
# [BATCH ep1_b30] packet/sparta shape=(200000, 31)
# [BATCH ep1_b30] trained on 159831 rows.
# [BATCH ep1_b31] packet/sparta shape=(200000, 31)
# [BATCH ep1_b31] trained on 160050 rows.
# [BATCH ep1_b32] packet/sparta shape=(200000, 31)
# [BATCH ep1_b32] trained on 160053 rows.
# [BATCH ep1_b33] packet/sparta shape=(200000, 31)
# [BATCH ep1_b33] trained on 160017 rows.
# [BATCH ep1_b34] packet/sparta shape=(200000, 31)
# [BATCH ep1_b34] trained on 159704 rows.
# [BATCH ep1_b35] packet/sparta shape=(200000, 31)
# [BATCH ep1_b35] trained on 159858 rows.
# [BATCH ep1_b36] packet/sparta shape=(200000, 31)
# [BATCH ep1_b36] trained on 159960 rows.
# [BATCH ep1_b37] packet/sparta shape=(200000, 31)
# [BATCH ep1_b37] trained on 160119 rows.
# [BATCH ep1_b38] packet/sparta shape=(200000, 31)
# [BATCH ep1_b38] trained on 159925 rows.
# [BATCH ep1_b39] packet/sparta shape=(200000, 31)
# [BATCH ep1_b39] trained on 160182 rows.
# [BATCH ep1_b40] packet/sparta shape=(200000, 31)
# [BATCH ep1_b40] trained on 160038 rows.
# [BATCH ep1_b41] packet/sparta shape=(200000, 31)
# [BATCH ep1_b41] trained on 159879 rows.
# [BATCH ep1_b42] packet/sparta shape=(200000, 31)
# [BATCH ep1_b42] trained on 159993 rows.
# [BATCH ep1_b43] packet/sparta shape=(200000, 31)
# [BATCH ep1_b43] trained on 160233 rows.
# [BATCH ep1_b44] packet/sparta shape=(200000, 31)
# [BATCH ep1_b44] trained on 159888 rows.
# [BATCH ep1_b45] packet/sparta shape=(200000, 31)
# [BATCH ep1_b45] trained on 160168 rows.
# [BATCH ep1_b46] packet/sparta shape=(200000, 31)
# [BATCH ep1_b46] trained on 160260 rows.
# [BATCH ep1_b47] packet/sparta shape=(200000, 31)
# [BATCH ep1_b47] trained on 160262 rows.
# [BATCH ep1_b48] packet/sparta shape=(200000, 31)
# [BATCH ep1_b48] trained on 160489 rows.
# [BATCH ep1_b49] packet/sparta shape=(200000, 31)
# [BATCH ep1_b49] trained on 160118 rows.
# [BATCH ep1_b50] packet/sparta shape=(200000, 31)
# [BATCH ep1_b50] trained on 159969 rows.
# [BATCH ep1_b51] packet/sparta shape=(200000, 31)
# [BATCH ep1_b51] trained on 160214 rows.
# [BATCH ep1_b52] packet/sparta shape=(200000, 31)
# [BATCH ep1_b52] trained on 159715 rows.
# [BATCH ep1_b53] packet/sparta shape=(200000, 31)
# [BATCH ep1_b53] trained on 160051 rows.
# [BATCH ep1_b54] packet/sparta shape=(200000, 31)
# [BATCH ep1_b54] trained on 159978 rows.
# [BATCH ep1_b55] packet/sparta shape=(200000, 31)
# [BATCH ep1_b55] trained on 160055 rows.
# [BATCH ep1_b56] packet/sparta shape=(200000, 31)
# [BATCH ep1_b56] trained on 160000 rows.
# [BATCH ep1_b57] packet/sparta shape=(200000, 31)
# [BATCH ep1_b57] trained on 159849 rows.
# [BATCH ep1_b58] packet/sparta shape=(200000, 31)
# [BATCH ep1_b58] trained on 159949 rows.
# [BATCH ep1_b59] packet/sparta shape=(200000, 31)
# [BATCH ep1_b59] trained on 159881 rows.
# [BATCH ep1_b60] packet/sparta shape=(200000, 31)
# [BATCH ep1_b60] trained on 160045 rows.
# [BATCH ep1_b61] packet/sparta shape=(200000, 31)
# [BATCH ep1_b61] trained on 160115 rows.
# [BATCH ep1_b62] packet/sparta shape=(200000, 31)
# [BATCH ep1_b62] trained on 160432 rows.
# [BATCH ep1_b63] packet/sparta shape=(200000, 31)
# [BATCH ep1_b63] trained on 159970 rows.
# [BATCH ep1_b64] packet/sparta shape=(200000, 31)
# [BATCH ep1_b64] trained on 159883 rows.
# [BATCH ep1_b65] packet/sparta shape=(200000, 31)
# [BATCH ep1_b65] trained on 160077 rows.
# [BATCH ep1_b66] packet/sparta shape=(200000, 31)
# [BATCH ep1_b66] trained on 160137 rows.
# [BATCH ep1_b67] packet/sparta shape=(200000, 31)
# [BATCH ep1_b67] trained on 160151 rows.
# [BATCH ep1_b68] packet/sparta shape=(200000, 31)
# [BATCH ep1_b68] trained on 160077 rows.
# [BATCH ep1_b69] packet/sparta shape=(200000, 31)
# [BATCH ep1_b69] trained on 160034 rows.
# [BATCH ep1_b70] packet/sparta shape=(200000, 31)
# [BATCH ep1_b70] trained on 159892 rows.
# [BATCH ep1_b71] packet/sparta shape=(200000, 31)
# [BATCH ep1_b71] trained on 159960 rows.
# [BATCH ep1_b72] packet/sparta shape=(200000, 31)
# [BATCH ep1_b72] trained on 159965 rows.
# [BATCH ep1_b73] packet/sparta shape=(200000, 31)
# [BATCH ep1_b73] trained on 160152 rows.
# [BATCH ep1_b74] packet/sparta shape=(200000, 31)
# [BATCH ep1_b74] trained on 159828 rows.
# [BATCH ep1_b75] packet/sparta shape=(200000, 31)
# [BATCH ep1_b75] trained on 160143 rows.
# [BATCH ep1_b76] packet/sparta shape=(200000, 31)
# [BATCH ep1_b76] trained on 159963 rows.
# [BATCH ep1_b77] packet/sparta shape=(200000, 31)
# [BATCH ep1_b77] trained on 160084 rows.
# [BATCH ep1_b78] packet/sparta shape=(200000, 31)
# [BATCH ep1_b78] trained on 160085 rows.
# [BATCH ep1_b79] packet/sparta shape=(200000, 31)
# [BATCH ep1_b79] trained on 160009 rows.
# [BATCH ep1_b80] packet/sparta shape=(200000, 31)
# [BATCH ep1_b80] trained on 160143 rows.
# [BATCH ep1_b81] packet/sparta shape=(200000, 31)
# [BATCH ep1_b81] trained on 160220 rows.
# [BATCH ep1_b82] packet/sparta shape=(200000, 31)
# [BATCH ep1_b82] trained on 159988 rows.
# [BATCH ep1_b83] packet/sparta shape=(200000, 31)
# [BATCH ep1_b83] trained on 159941 rows.
# [BATCH ep1_b84] packet/sparta shape=(200000, 31)
# [BATCH ep1_b84] trained on 159813 rows.
# [BATCH ep1_b85] packet/sparta shape=(200000, 31)
# [BATCH ep1_b85] trained on 160223 rows.
# [BATCH ep1_b86] packet/sparta shape=(200000, 31)
# [BATCH ep1_b86] trained on 160119 rows.
# [BATCH ep1_b87] packet/sparta shape=(200000, 31)
# [BATCH ep1_b87] trained on 160054 rows.
# [BATCH ep1_b88] packet/sparta shape=(200000, 31)
# [BATCH ep1_b88] trained on 160099 rows.
# [BATCH ep1_b89] packet/sparta shape=(200000, 31)
# [BATCH ep1_b89] trained on 159755 rows.
# [BATCH ep1_b90] packet/sparta shape=(200000, 31)
# [BATCH ep1_b90] trained on 159984 rows.
# [BATCH ep1_b91] packet/sparta shape=(200000, 31)
# [BATCH ep1_b91] trained on 159938 rows.
# [BATCH ep1_b92] packet/sparta shape=(200000, 31)
# [BATCH ep1_b92] trained on 159863 rows.
# [BATCH ep1_b93] packet/sparta shape=(200000, 31)
# [BATCH ep1_b93] trained on 160430 rows.
# [BATCH ep1_b94] packet/sparta shape=(200000, 31)
# [BATCH ep1_b94] trained on 159699 rows.
# [BATCH ep1_b95] packet/sparta shape=(200000, 31)
# [BATCH ep1_b95] trained on 159839 rows.
# [BATCH ep1_b96] packet/sparta shape=(200000, 31)
# [BATCH ep1_b96] trained on 159798 rows.
# [BATCH ep1_b97] packet/sparta shape=(200000, 31)
# [BATCH ep1_b97] trained on 160115 rows.
# [BATCH ep1_b98] packet/sparta shape=(200000, 31)
# [BATCH ep1_b98] trained on 159873 rows.
# [BATCH ep1_b99] packet/sparta shape=(200000, 31)
# [BATCH ep1_b99] trained on 159862 rows.
# [BATCH ep1_b100] packet/sparta shape=(200000, 31)
# [BATCH ep1_b100] trained on 159651 rows.
# [BATCH ep1_b101] packet/sparta shape=(200000, 31)
# [BATCH ep1_b101] trained on 159870 rows.
# [BATCH ep1_b102] packet/sparta shape=(200000, 31)
# [BATCH ep1_b102] trained on 159893 rows.
# [BATCH ep1_b103] packet/sparta shape=(200000, 31)
# [BATCH ep1_b103] trained on 159966 rows.
# [BATCH ep1_b104] packet/sparta shape=(200000, 31)
# [BATCH ep1_b104] trained on 160035 rows.
# [BATCH ep1_b105] packet/sparta shape=(200000, 31)
# [BATCH ep1_b105] trained on 159920 rows.
# [BATCH ep1_b106] packet/sparta shape=(200000, 31)
# [BATCH ep1_b106] trained on 159936 rows.
# [BATCH ep1_b107] packet/sparta shape=(200000, 31)
# [BATCH ep1_b107] trained on 159738 rows.
# [BATCH ep1_b108] packet/sparta shape=(200000, 31)
# [BATCH ep1_b108] trained on 160117 rows.
# [BATCH ep1_b109] packet/sparta shape=(200000, 31)
# [BATCH ep1_b109] trained on 160142 rows.
# [BATCH ep1_b110] packet/sparta shape=(76140, 31)
# [BATCH ep1_b110] trained on 60809 rows.
# [BATCH ep1_b111] packet/scan_A shape=(111392, 31)
# [BATCH ep1_b111] trained on 89064 rows.
# [BATCH ep1_b112] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b112] trained on 159753 rows.
# [BATCH ep1_b113] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b113] trained on 160160 rows.
# [BATCH ep1_b114] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b114] trained on 159905 rows.
# [BATCH ep1_b115] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b115] trained on 160051 rows.
# [BATCH ep1_b116] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b116] trained on 160488 rows.
# [BATCH ep1_b117] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b117] trained on 160049 rows.
# [BATCH ep1_b118] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b118] trained on 160330 rows.
# [BATCH ep1_b119] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b119] trained on 160395 rows.
# [BATCH ep1_b120] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b120] trained on 159874 rows.
# [BATCH ep1_b121] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b121] trained on 160559 rows.
# [BATCH ep1_b122] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b122] trained on 160201 rows.
# [BATCH ep1_b123] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b123] trained on 160181 rows.
# [BATCH ep1_b124] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b124] trained on 160176 rows.
# [BATCH ep1_b125] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b125] trained on 159872 rows.
# [BATCH ep1_b126] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b126] trained on 160188 rows.
# [BATCH ep1_b127] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b127] trained on 159921 rows.
# [BATCH ep1_b128] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b128] trained on 160097 rows.
# [BATCH ep1_b129] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b129] trained on 159898 rows.
# [BATCH ep1_b130] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b130] trained on 159933 rows.
# [BATCH ep1_b131] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b131] trained on 160118 rows.
# [BATCH ep1_b132] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b132] trained on 159958 rows.
# [BATCH ep1_b133] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b133] trained on 160427 rows.
# [BATCH ep1_b134] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b134] trained on 160096 rows.
# [BATCH ep1_b135] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b135] trained on 160108 rows.
# [BATCH ep1_b136] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b136] trained on 160005 rows.
# [BATCH ep1_b137] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b137] trained on 159728 rows.
# [BATCH ep1_b138] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b138] trained on 159866 rows.
# [BATCH ep1_b139] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b139] trained on 159943 rows.
# [BATCH ep1_b140] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b140] trained on 160064 rows.
# [BATCH ep1_b141] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b141] trained on 159978 rows.
# [BATCH ep1_b142] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b142] trained on 160366 rows.
# [BATCH ep1_b143] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b143] trained on 159973 rows.
# [BATCH ep1_b144] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b144] trained on 159925 rows.
# [BATCH ep1_b145] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b145] trained on 160162 rows.
# [BATCH ep1_b146] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b146] trained on 159921 rows.
# [BATCH ep1_b147] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b147] trained on 160148 rows.
# [BATCH ep1_b148] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b148] trained on 160039 rows.
# [BATCH ep1_b149] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b149] trained on 159966 rows.
# [BATCH ep1_b150] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b150] trained on 160026 rows.
# [BATCH ep1_b151] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b151] trained on 160018 rows.
# [BATCH ep1_b152] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b152] trained on 160161 rows.
# [BATCH ep1_b153] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b153] trained on 160254 rows.
# [BATCH ep1_b154] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b154] trained on 160201 rows.
# [BATCH ep1_b155] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b155] trained on 160086 rows.
# [BATCH ep1_b156] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b156] trained on 160007 rows.
# [BATCH ep1_b157] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b157] trained on 160139 rows.
# [BATCH ep1_b158] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b158] trained on 160040 rows.
# [BATCH ep1_b159] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b159] trained on 159907 rows.
# [BATCH ep1_b160] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b160] trained on 159878 rows.
# [BATCH ep1_b161] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep1_b161] trained on 160059 rows.
# [BATCH ep1_b162] packet/mqtt_bruteforce shape=(45316, 31)
# [BATCH ep1_b162] trained on 36224 rows.
# [BATCH ep1_b163] packet/scan_sU shape=(200000, 31)
# [BATCH ep1_b163] trained on 159929 rows.
# [BATCH ep1_b164] packet/scan_sU shape=(33255, 31)
# [BATCH ep1_b164] trained on 26627 rows.
# [BATCH ep1_b165] uniflow/normal shape=(171836, 19)
# [BATCH ep1_b165] trained on 137415 rows.
# [BATCH ep1_b166] uniflow/sparta shape=(182407, 19)
# [BATCH ep1_b166] trained on 145924 rows.
# [BATCH ep1_b167] uniflow/scan_A shape=(51358, 19)
# [BATCH ep1_b167] trained on 41079 rows.
# [BATCH ep1_b168] uniflow/mqtt_bruteforce shape=(33079, 19)
# [BATCH ep1_b168] trained on 26484 rows.
# [BATCH ep1_b169] uniflow/scan_sU shape=(56845, 19)
# [BATCH ep1_b169] trained on 45530 rows.
# [BATCH ep1_b170] biflow/normal shape=(86008, 32)
# [BATCH ep1_b170] trained on 68763 rows.
# [BATCH ep1_b171] biflow/sparta shape=(91318, 32)
# [BATCH ep1_b171] trained on 73026 rows.
# [BATCH ep1_b172] biflow/scan_A shape=(25693, 32)
# [BATCH ep1_b172] trained on 20520 rows.
# [BATCH ep1_b173] biflow/mqtt_bruteforce shape=(16696, 32)
# [BATCH ep1_b173] trained on 13341 rows.
# [BATCH ep1_b174] biflow/scan_sU shape=(39664, 32)
# [BATCH ep1_b174] trained on 31702 rows.
# [EPOCH 1] Val Acc=0.8164  F1=0.4494
#
# === EPOCH 2/3 ===
# [BATCH ep2_b175] packet/normal shape=(200000, 31)
# [BATCH ep2_b175] trained on 160143 rows.
# [BATCH ep2_b176] packet/normal shape=(200000, 31)
# [BATCH ep2_b176] trained on 159739 rows.
# [BATCH ep2_b177] packet/normal shape=(200000, 31)
# [BATCH ep2_b177] trained on 159876 rows.
# [BATCH ep2_b178] packet/normal shape=(200000, 31)
# [BATCH ep2_b178] trained on 160125 rows.
# [BATCH ep2_b179] packet/normal shape=(200000, 31)
# [BATCH ep2_b179] trained on 160153 rows.
# [BATCH ep2_b180] packet/normal shape=(56231, 31)
# [BATCH ep2_b180] trained on 44890 rows.
# [BATCH ep2_b181] packet/sparta shape=(200000, 31)
# [BATCH ep2_b181] trained on 159948 rows.
# [BATCH ep2_b182] packet/sparta shape=(200000, 31)
# [BATCH ep2_b182] trained on 159993 rows.
# [BATCH ep2_b183] packet/sparta shape=(200000, 31)
# [BATCH ep2_b183] trained on 160185 rows.
# [BATCH ep2_b184] packet/sparta shape=(200000, 31)
# [BATCH ep2_b184] trained on 160285 rows.
# [BATCH ep2_b185] packet/sparta shape=(200000, 31)
# [BATCH ep2_b185] trained on 159731 rows.
# [BATCH ep2_b186] packet/sparta shape=(200000, 31)
# [BATCH ep2_b186] trained on 160056 rows.
# [BATCH ep2_b187] packet/sparta shape=(200000, 31)
# [BATCH ep2_b187] trained on 159800 rows.
# [BATCH ep2_b188] packet/sparta shape=(200000, 31)
# [BATCH ep2_b188] trained on 159974 rows.
# [BATCH ep2_b189] packet/sparta shape=(200000, 31)
# [BATCH ep2_b189] trained on 160050 rows.
# [BATCH ep2_b190] packet/sparta shape=(200000, 31)
# [BATCH ep2_b190] trained on 159962 rows.
# [BATCH ep2_b191] packet/sparta shape=(200000, 31)
# [BATCH ep2_b191] trained on 160114 rows.
# [BATCH ep2_b192] packet/sparta shape=(200000, 31)
# [BATCH ep2_b192] trained on 160141 rows.
# [BATCH ep2_b193] packet/sparta shape=(200000, 31)
# [BATCH ep2_b193] trained on 160016 rows.
# [BATCH ep2_b194] packet/sparta shape=(200000, 31)
# [BATCH ep2_b194] trained on 160042 rows.
# [BATCH ep2_b195] packet/sparta shape=(200000, 31)
# [BATCH ep2_b195] trained on 160036 rows.
# [BATCH ep2_b196] packet/sparta shape=(200000, 31)
# [BATCH ep2_b196] trained on 159877 rows.
# [BATCH ep2_b197] packet/sparta shape=(200000, 31)
# [BATCH ep2_b197] trained on 159990 rows.
# [BATCH ep2_b198] packet/sparta shape=(200000, 31)
# [BATCH ep2_b198] trained on 160044 rows.
# [BATCH ep2_b199] packet/sparta shape=(200000, 31)
# [BATCH ep2_b199] trained on 159731 rows.
# [BATCH ep2_b200] packet/sparta shape=(200000, 31)
# [BATCH ep2_b200] trained on 159887 rows.
# [BATCH ep2_b201] packet/sparta shape=(200000, 31)
# [BATCH ep2_b201] trained on 160401 rows.
# [BATCH ep2_b202] packet/sparta shape=(200000, 31)
# [BATCH ep2_b202] trained on 160205 rows.
# [BATCH ep2_b203] packet/sparta shape=(200000, 31)
# [BATCH ep2_b203] trained on 160177 rows.
# [BATCH ep2_b204] packet/sparta shape=(200000, 31)
# [BATCH ep2_b204] trained on 159890 rows.
# [BATCH ep2_b205] packet/sparta shape=(200000, 31)
# [BATCH ep2_b205] trained on 160183 rows.
# [BATCH ep2_b206] packet/sparta shape=(200000, 31)
# [BATCH ep2_b206] trained on 160223 rows.
# [BATCH ep2_b207] packet/sparta shape=(200000, 31)
# [BATCH ep2_b207] trained on 160060 rows.
# [BATCH ep2_b208] packet/sparta shape=(200000, 31)
# [BATCH ep2_b208] trained on 159764 rows.
# [BATCH ep2_b209] packet/sparta shape=(200000, 31)
# [BATCH ep2_b209] trained on 159938 rows.
# [BATCH ep2_b210] packet/sparta shape=(200000, 31)
# [BATCH ep2_b210] trained on 160298 rows.
# [BATCH ep2_b211] packet/sparta shape=(200000, 31)
# [BATCH ep2_b211] trained on 160122 rows.
# [BATCH ep2_b212] packet/sparta shape=(200000, 31)
# [BATCH ep2_b212] trained on 160296 rows.
# [BATCH ep2_b213] packet/sparta shape=(200000, 31)
# [BATCH ep2_b213] trained on 160242 rows.
# [BATCH ep2_b214] packet/sparta shape=(200000, 31)
# [BATCH ep2_b214] trained on 159903 rows.
# [BATCH ep2_b215] packet/sparta shape=(200000, 31)
# [BATCH ep2_b215] trained on 159911 rows.
# [BATCH ep2_b216] packet/sparta shape=(200000, 31)
# [BATCH ep2_b216] trained on 160185 rows.
# [BATCH ep2_b217] packet/sparta shape=(200000, 31)
# [BATCH ep2_b217] trained on 160014 rows.
# [BATCH ep2_b218] packet/sparta shape=(200000, 31)
# [BATCH ep2_b218] trained on 160033 rows.
# [BATCH ep2_b219] packet/sparta shape=(200000, 31)
# [BATCH ep2_b219] trained on 159968 rows.
# [BATCH ep2_b220] packet/sparta shape=(200000, 31)
# [BATCH ep2_b220] trained on 160299 rows.
# [BATCH ep2_b221] packet/sparta shape=(200000, 31)
# [BATCH ep2_b221] trained on 160023 rows.
# [BATCH ep2_b222] packet/sparta shape=(200000, 31)
# [BATCH ep2_b222] trained on 160090 rows.
# [BATCH ep2_b223] packet/sparta shape=(200000, 31)
# [BATCH ep2_b223] trained on 159976 rows.
# [BATCH ep2_b224] packet/sparta shape=(200000, 31)
# [BATCH ep2_b224] trained on 159826 rows.
# [BATCH ep2_b225] packet/sparta shape=(200000, 31)
# [BATCH ep2_b225] trained on 160121 rows.
# [BATCH ep2_b226] packet/sparta shape=(200000, 31)
# [BATCH ep2_b226] trained on 160116 rows.
# [BATCH ep2_b227] packet/sparta shape=(200000, 31)
# [BATCH ep2_b227] trained on 159825 rows.
# [BATCH ep2_b228] packet/sparta shape=(200000, 31)
# [BATCH ep2_b228] trained on 159716 rows.
# [BATCH ep2_b229] packet/sparta shape=(200000, 31)
# [BATCH ep2_b229] trained on 159687 rows.
# [BATCH ep2_b230] packet/sparta shape=(200000, 31)
# [BATCH ep2_b230] trained on 159709 rows.
# [BATCH ep2_b231] packet/sparta shape=(200000, 31)
# [BATCH ep2_b231] trained on 159982 rows.
# [BATCH ep2_b232] packet/sparta shape=(200000, 31)
# [BATCH ep2_b232] trained on 159942 rows.
# [BATCH ep2_b233] packet/sparta shape=(200000, 31)
# [BATCH ep2_b233] trained on 159685 rows.
# [BATCH ep2_b234] packet/sparta shape=(200000, 31)
# [BATCH ep2_b234] trained on 160073 rows.
# [BATCH ep2_b235] packet/sparta shape=(200000, 31)
# [BATCH ep2_b235] trained on 160080 rows.
# [BATCH ep2_b236] packet/sparta shape=(200000, 31)
# [BATCH ep2_b236] trained on 160299 rows.
# [BATCH ep2_b237] packet/sparta shape=(200000, 31)
# [BATCH ep2_b237] trained on 160227 rows.
# [BATCH ep2_b238] packet/sparta shape=(200000, 31)
# [BATCH ep2_b238] trained on 159993 rows.
# [BATCH ep2_b239] packet/sparta shape=(200000, 31)
# [BATCH ep2_b239] trained on 160161 rows.
# [BATCH ep2_b240] packet/sparta shape=(200000, 31)
# [BATCH ep2_b240] trained on 159980 rows.
# [BATCH ep2_b241] packet/sparta shape=(200000, 31)
# [BATCH ep2_b241] trained on 159656 rows.
# [BATCH ep2_b242] packet/sparta shape=(200000, 31)
# [BATCH ep2_b242] trained on 159918 rows.
# [BATCH ep2_b243] packet/sparta shape=(200000, 31)
# [BATCH ep2_b243] trained on 159913 rows.
# [BATCH ep2_b244] packet/sparta shape=(200000, 31)
# [BATCH ep2_b244] trained on 159890 rows.
# [BATCH ep2_b245] packet/sparta shape=(200000, 31)
# [BATCH ep2_b245] trained on 160041 rows.
# [BATCH ep2_b246] packet/sparta shape=(200000, 31)
# [BATCH ep2_b246] trained on 160000 rows.
# [BATCH ep2_b247] packet/sparta shape=(200000, 31)
# [BATCH ep2_b247] trained on 159921 rows.
# [BATCH ep2_b248] packet/sparta shape=(200000, 31)
# [BATCH ep2_b248] trained on 160073 rows.
# [BATCH ep2_b249] packet/sparta shape=(200000, 31)
# [BATCH ep2_b249] trained on 160200 rows.
# [BATCH ep2_b250] packet/sparta shape=(200000, 31)
# [BATCH ep2_b250] trained on 160146 rows.
# [BATCH ep2_b251] packet/sparta shape=(200000, 31)
# [BATCH ep2_b251] trained on 160163 rows.
# [BATCH ep2_b252] packet/sparta shape=(200000, 31)
# [BATCH ep2_b252] trained on 159875 rows.
# [BATCH ep2_b253] packet/sparta shape=(200000, 31)
# [BATCH ep2_b253] trained on 160141 rows.
# [BATCH ep2_b254] packet/sparta shape=(200000, 31)
# [BATCH ep2_b254] trained on 159908 rows.
# [BATCH ep2_b255] packet/sparta shape=(200000, 31)
# [BATCH ep2_b255] trained on 160078 rows.
# [BATCH ep2_b256] packet/sparta shape=(200000, 31)
# [BATCH ep2_b256] trained on 160124 rows.
# [BATCH ep2_b257] packet/sparta shape=(200000, 31)
# [BATCH ep2_b257] trained on 160003 rows.
# [BATCH ep2_b258] packet/sparta shape=(200000, 31)
# [BATCH ep2_b258] trained on 159884 rows.
# [BATCH ep2_b259] packet/sparta shape=(200000, 31)
# [BATCH ep2_b259] trained on 159870 rows.
# [BATCH ep2_b260] packet/sparta shape=(200000, 31)
# [BATCH ep2_b260] trained on 159940 rows.
# [BATCH ep2_b261] packet/sparta shape=(200000, 31)
# [BATCH ep2_b261] trained on 160145 rows.
# [BATCH ep2_b262] packet/sparta shape=(200000, 31)
# [BATCH ep2_b262] trained on 160064 rows.
# [BATCH ep2_b263] packet/sparta shape=(200000, 31)
# [BATCH ep2_b263] trained on 160023 rows.
# [BATCH ep2_b264] packet/sparta shape=(200000, 31)
# [BATCH ep2_b264] trained on 159973 rows.
# [BATCH ep2_b265] packet/sparta shape=(200000, 31)
# [BATCH ep2_b265] trained on 160081 rows.
# [BATCH ep2_b266] packet/sparta shape=(200000, 31)
# [BATCH ep2_b266] trained on 160046 rows.
# [BATCH ep2_b267] packet/sparta shape=(200000, 31)
# [BATCH ep2_b267] trained on 159919 rows.
# [BATCH ep2_b268] packet/sparta shape=(200000, 31)
# [BATCH ep2_b268] trained on 160010 rows.
# [BATCH ep2_b269] packet/sparta shape=(200000, 31)
# [BATCH ep2_b269] trained on 159685 rows.
# [BATCH ep2_b270] packet/sparta shape=(200000, 31)
# [BATCH ep2_b270] trained on 159962 rows.
# [BATCH ep2_b271] packet/sparta shape=(200000, 31)
# [BATCH ep2_b271] trained on 159563 rows.
# [BATCH ep2_b272] packet/sparta shape=(200000, 31)
# [BATCH ep2_b272] trained on 159983 rows.
# [BATCH ep2_b273] packet/sparta shape=(200000, 31)
# [BATCH ep2_b273] trained on 160067 rows.
# [BATCH ep2_b274] packet/sparta shape=(200000, 31)
# [BATCH ep2_b274] trained on 159920 rows.
# [BATCH ep2_b275] packet/sparta shape=(200000, 31)
# [BATCH ep2_b275] trained on 160122 rows.
# [BATCH ep2_b276] packet/sparta shape=(200000, 31)
# [BATCH ep2_b276] trained on 160071 rows.
# [BATCH ep2_b277] packet/sparta shape=(200000, 31)
# [BATCH ep2_b277] trained on 159952 rows.
# [BATCH ep2_b278] packet/sparta shape=(200000, 31)
# [BATCH ep2_b278] trained on 159419 rows.
# [BATCH ep2_b279] packet/sparta shape=(200000, 31)
# [BATCH ep2_b279] trained on 159804 rows.
# [BATCH ep2_b280] packet/sparta shape=(200000, 31)
# [BATCH ep2_b280] trained on 160353 rows.
# [BATCH ep2_b281] packet/sparta shape=(200000, 31)
# [BATCH ep2_b281] trained on 159872 rows.
# [BATCH ep2_b282] packet/sparta shape=(200000, 31)
# [BATCH ep2_b282] trained on 160116 rows.
# [BATCH ep2_b283] packet/sparta shape=(200000, 31)
# [BATCH ep2_b283] trained on 159979 rows.
# [BATCH ep2_b284] packet/sparta shape=(76140, 31)
# [BATCH ep2_b284] trained on 60848 rows.
# [BATCH ep2_b285] packet/scan_A shape=(111392, 31)
# [BATCH ep2_b285] trained on 89102 rows.
# [BATCH ep2_b286] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b286] trained on 160045 rows.
# [BATCH ep2_b287] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b287] trained on 160109 rows.
# [BATCH ep2_b288] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b288] trained on 159869 rows.
# [BATCH ep2_b289] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b289] trained on 159921 rows.
# [BATCH ep2_b290] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b290] trained on 160021 rows.
# [BATCH ep2_b291] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b291] trained on 159773 rows.
# [BATCH ep2_b292] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b292] trained on 159916 rows.
# [BATCH ep2_b293] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b293] trained on 159987 rows.
# [BATCH ep2_b294] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b294] trained on 159896 rows.
# [BATCH ep2_b295] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b295] trained on 160134 rows.
# [BATCH ep2_b296] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b296] trained on 160210 rows.
# [BATCH ep2_b297] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b297] trained on 160048 rows.
# [BATCH ep2_b298] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b298] trained on 160191 rows.
# [BATCH ep2_b299] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b299] trained on 160105 rows.
# [BATCH ep2_b300] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b300] trained on 160220 rows.
# [BATCH ep2_b301] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b301] trained on 159627 rows.
# [BATCH ep2_b302] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b302] trained on 159658 rows.
# [BATCH ep2_b303] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b303] trained on 160054 rows.
# [BATCH ep2_b304] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b304] trained on 159818 rows.
# [BATCH ep2_b305] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b305] trained on 159874 rows.
# [BATCH ep2_b306] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b306] trained on 160008 rows.
# [BATCH ep2_b307] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b307] trained on 159946 rows.
# [BATCH ep2_b308] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b308] trained on 160067 rows.
# [BATCH ep2_b309] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b309] trained on 160231 rows.
# [BATCH ep2_b310] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b310] trained on 160412 rows.
# [BATCH ep2_b311] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b311] trained on 159881 rows.
# [BATCH ep2_b312] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b312] trained on 160020 rows.
# [BATCH ep2_b313] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b313] trained on 159701 rows.
# [BATCH ep2_b314] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b314] trained on 160394 rows.
# [BATCH ep2_b315] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b315] trained on 159714 rows.
# [BATCH ep2_b316] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b316] trained on 159970 rows.
# [BATCH ep2_b317] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b317] trained on 160087 rows.
# [BATCH ep2_b318] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b318] trained on 160166 rows.
# [BATCH ep2_b319] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b319] trained on 160127 rows.
# [BATCH ep2_b320] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b320] trained on 159916 rows.
# [BATCH ep2_b321] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b321] trained on 160112 rows.
# [BATCH ep2_b322] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b322] trained on 160086 rows.
# [BATCH ep2_b323] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b323] trained on 160022 rows.
# [BATCH ep2_b324] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b324] trained on 160142 rows.
# [BATCH ep2_b325] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b325] trained on 159920 rows.
# [BATCH ep2_b326] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b326] trained on 159916 rows.
# [BATCH ep2_b327] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b327] trained on 160031 rows.
# [BATCH ep2_b328] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b328] trained on 160380 rows.
# [BATCH ep2_b329] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b329] trained on 160011 rows.
# [BATCH ep2_b330] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b330] trained on 159992 rows.
# [BATCH ep2_b331] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b331] trained on 160007 rows.
# [BATCH ep2_b332] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b332] trained on 160158 rows.
# [BATCH ep2_b333] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b333] trained on 159821 rows.
# [BATCH ep2_b334] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b334] trained on 159967 rows.
# [BATCH ep2_b335] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep2_b335] trained on 160172 rows.
# [BATCH ep2_b336] packet/mqtt_bruteforce shape=(45316, 31)
# [BATCH ep2_b336] trained on 36366 rows.
# [BATCH ep2_b337] packet/scan_sU shape=(200000, 31)
# [BATCH ep2_b337] trained on 159653 rows.
# [BATCH ep2_b338] packet/scan_sU shape=(33255, 31)
# [BATCH ep2_b338] trained on 26557 rows.
# [BATCH ep2_b339] uniflow/normal shape=(171836, 19)
# [BATCH ep2_b339] trained on 137446 rows.
# [BATCH ep2_b340] uniflow/sparta shape=(182407, 19)
# [BATCH ep2_b340] trained on 145761 rows.
# [BATCH ep2_b341] uniflow/scan_A shape=(51358, 19)
# [BATCH ep2_b341] trained on 41162 rows.
# [BATCH ep2_b342] uniflow/mqtt_bruteforce shape=(33079, 19)
# [BATCH ep2_b342] trained on 26441 rows.
# [BATCH ep2_b343] uniflow/scan_sU shape=(56845, 19)
# [BATCH ep2_b343] trained on 45283 rows.
# [BATCH ep2_b344] biflow/normal shape=(86008, 32)
# [BATCH ep2_b344] trained on 68693 rows.
# [BATCH ep2_b345] biflow/sparta shape=(91318, 32)
# [BATCH ep2_b345] trained on 73075 rows.
# [BATCH ep2_b346] biflow/scan_A shape=(25693, 32)
# [BATCH ep2_b346] trained on 20577 rows.
# [BATCH ep2_b347] biflow/mqtt_bruteforce shape=(16696, 32)
# [BATCH ep2_b347] trained on 13437 rows.
# [BATCH ep2_b348] biflow/scan_sU shape=(39664, 32)
# [BATCH ep2_b348] trained on 31754 rows.
# [EPOCH 2] Val Acc=0.8174  F1=0.4497
#
# === EPOCH 3/3 ===
# [BATCH ep3_b349] packet/normal shape=(200000, 31)
# [BATCH ep3_b349] trained on 160161 rows.
# [BATCH ep3_b350] packet/normal shape=(200000, 31)
# [BATCH ep3_b350] trained on 159806 rows.
# [BATCH ep3_b351] packet/normal shape=(200000, 31)
# [BATCH ep3_b351] trained on 160045 rows.
# [BATCH ep3_b352] packet/normal shape=(200000, 31)
# [BATCH ep3_b352] trained on 160035 rows.
# [BATCH ep3_b353] packet/normal shape=(200000, 31)
# [BATCH ep3_b353] trained on 159836 rows.
# [BATCH ep3_b354] packet/normal shape=(56231, 31)
# [BATCH ep3_b354] trained on 44945 rows.
# [BATCH ep3_b355] packet/sparta shape=(200000, 31)
# [BATCH ep3_b355] trained on 160321 rows.
# [BATCH ep3_b356] packet/sparta shape=(200000, 31)
# [BATCH ep3_b356] trained on 160163 rows.
# [BATCH ep3_b357] packet/sparta shape=(200000, 31)
# [BATCH ep3_b357] trained on 159941 rows.
# [BATCH ep3_b358] packet/sparta shape=(200000, 31)
# [BATCH ep3_b358] trained on 160029 rows.
# [BATCH ep3_b359] packet/sparta shape=(200000, 31)
# [BATCH ep3_b359] trained on 160063 rows.
# [BATCH ep3_b360] packet/sparta shape=(200000, 31)
# [BATCH ep3_b360] trained on 160173 rows.
# [BATCH ep3_b361] packet/sparta shape=(200000, 31)
# [BATCH ep3_b361] trained on 160152 rows.
# [BATCH ep3_b362] packet/sparta shape=(200000, 31)
# [BATCH ep3_b362] trained on 160279 rows.
# [BATCH ep3_b363] packet/sparta shape=(200000, 31)
# [BATCH ep3_b363] trained on 159839 rows.
# [BATCH ep3_b364] packet/sparta shape=(200000, 31)
# [BATCH ep3_b364] trained on 160384 rows.
# [BATCH ep3_b365] packet/sparta shape=(200000, 31)
# [BATCH ep3_b365] trained on 160051 rows.
# [BATCH ep3_b366] packet/sparta shape=(200000, 31)
# [BATCH ep3_b366] trained on 159816 rows.
# [BATCH ep3_b367] packet/sparta shape=(200000, 31)
# [BATCH ep3_b367] trained on 159867 rows.
# [BATCH ep3_b368] packet/sparta shape=(200000, 31)
# [BATCH ep3_b368] trained on 160175 rows.
# [BATCH ep3_b369] packet/sparta shape=(200000, 31)
# [BATCH ep3_b369] trained on 160191 rows.
# [BATCH ep3_b370] packet/sparta shape=(200000, 31)
# [BATCH ep3_b370] trained on 160051 rows.
# [BATCH ep3_b371] packet/sparta shape=(200000, 31)
# [BATCH ep3_b371] trained on 160194 rows.
# [BATCH ep3_b372] packet/sparta shape=(200000, 31)
# [BATCH ep3_b372] trained on 159992 rows.
# [BATCH ep3_b373] packet/sparta shape=(200000, 31)
# [BATCH ep3_b373] trained on 160134 rows.
# [BATCH ep3_b374] packet/sparta shape=(200000, 31)
# [BATCH ep3_b374] trained on 160340 rows.
# [BATCH ep3_b375] packet/sparta shape=(200000, 31)
# [BATCH ep3_b375] trained on 160058 rows.
# [BATCH ep3_b376] packet/sparta shape=(200000, 31)
# [BATCH ep3_b376] trained on 160155 rows.
# [BATCH ep3_b377] packet/sparta shape=(200000, 31)
# [BATCH ep3_b377] trained on 160028 rows.
# [BATCH ep3_b378] packet/sparta shape=(200000, 31)
# [BATCH ep3_b378] trained on 159959 rows.
# [BATCH ep3_b379] packet/sparta shape=(200000, 31)
# [BATCH ep3_b379] trained on 160212 rows.
# [BATCH ep3_b380] packet/sparta shape=(200000, 31)
# [BATCH ep3_b380] trained on 160194 rows.
# [BATCH ep3_b381] packet/sparta shape=(200000, 31)
# [BATCH ep3_b381] trained on 159787 rows.
# [BATCH ep3_b382] packet/sparta shape=(200000, 31)
# [BATCH ep3_b382] trained on 159869 rows.
# [BATCH ep3_b383] packet/sparta shape=(200000, 31)
# [BATCH ep3_b383] trained on 160106 rows.
# [BATCH ep3_b384] packet/sparta shape=(200000, 31)
# [BATCH ep3_b384] trained on 159828 rows.
# [BATCH ep3_b385] packet/sparta shape=(200000, 31)
# [BATCH ep3_b385] trained on 159909 rows.
# [BATCH ep3_b386] packet/sparta shape=(200000, 31)
# [BATCH ep3_b386] trained on 159971 rows.
# [BATCH ep3_b387] packet/sparta shape=(200000, 31)
# [BATCH ep3_b387] trained on 159979 rows.
# [BATCH ep3_b388] packet/sparta shape=(200000, 31)
# [BATCH ep3_b388] trained on 160158 rows.
# [BATCH ep3_b389] packet/sparta shape=(200000, 31)
# [BATCH ep3_b389] trained on 159997 rows.
# [BATCH ep3_b390] packet/sparta shape=(200000, 31)
# [BATCH ep3_b390] trained on 159945 rows.
# [BATCH ep3_b391] packet/sparta shape=(200000, 31)
# [BATCH ep3_b391] trained on 159954 rows.
# [BATCH ep3_b392] packet/sparta shape=(200000, 31)
# [BATCH ep3_b392] trained on 159856 rows.
# [BATCH ep3_b393] packet/sparta shape=(200000, 31)
# [BATCH ep3_b393] trained on 159786 rows.
# [BATCH ep3_b394] packet/sparta shape=(200000, 31)
# [BATCH ep3_b394] trained on 159920 rows.
# [BATCH ep3_b395] packet/sparta shape=(200000, 31)
# [BATCH ep3_b395] trained on 159699 rows.
# [BATCH ep3_b396] packet/sparta shape=(200000, 31)
# [BATCH ep3_b396] trained on 160256 rows.
# [BATCH ep3_b397] packet/sparta shape=(200000, 31)
# [BATCH ep3_b397] trained on 159874 rows.
# [BATCH ep3_b398] packet/sparta shape=(200000, 31)
# [BATCH ep3_b398] trained on 160034 rows.
# [BATCH ep3_b399] packet/sparta shape=(200000, 31)
# [BATCH ep3_b399] trained on 160040 rows.
# [BATCH ep3_b400] packet/sparta shape=(200000, 31)
# [BATCH ep3_b400] trained on 159909 rows.
# [BATCH ep3_b401] packet/sparta shape=(200000, 31)
# [BATCH ep3_b401] trained on 160054 rows.
# [BATCH ep3_b402] packet/sparta shape=(200000, 31)
# [BATCH ep3_b402] trained on 159977 rows.
# [BATCH ep3_b403] packet/sparta shape=(200000, 31)
# [BATCH ep3_b403] trained on 160197 rows.
# [BATCH ep3_b404] packet/sparta shape=(200000, 31)
# [BATCH ep3_b404] trained on 160080 rows.
# [BATCH ep3_b405] packet/sparta shape=(200000, 31)
# [BATCH ep3_b405] trained on 160398 rows.
# [BATCH ep3_b406] packet/sparta shape=(200000, 31)
# [BATCH ep3_b406] trained on 159780 rows.
# [BATCH ep3_b407] packet/sparta shape=(200000, 31)
# [BATCH ep3_b407] trained on 160104 rows.
# [BATCH ep3_b408] packet/sparta shape=(200000, 31)
# [BATCH ep3_b408] trained on 160227 rows.
# [BATCH ep3_b409] packet/sparta shape=(200000, 31)
# [BATCH ep3_b409] trained on 159649 rows.
# [BATCH ep3_b410] packet/sparta shape=(200000, 31)
# [BATCH ep3_b410] trained on 159968 rows.
# [BATCH ep3_b411] packet/sparta shape=(200000, 31)
# [BATCH ep3_b411] trained on 159663 rows.
# [BATCH ep3_b412] packet/sparta shape=(200000, 31)
# [BATCH ep3_b412] trained on 160084 rows.
# [BATCH ep3_b413] packet/sparta shape=(200000, 31)
# [BATCH ep3_b413] trained on 160094 rows.
# [BATCH ep3_b414] packet/sparta shape=(200000, 31)
# [BATCH ep3_b414] trained on 159739 rows.
# [BATCH ep3_b415] packet/sparta shape=(200000, 31)
# [BATCH ep3_b415] trained on 160233 rows.
# [BATCH ep3_b416] packet/sparta shape=(200000, 31)
# [BATCH ep3_b416] trained on 160047 rows.
# [BATCH ep3_b417] packet/sparta shape=(200000, 31)
# [BATCH ep3_b417] trained on 160240 rows.
# [BATCH ep3_b418] packet/sparta shape=(200000, 31)
# [BATCH ep3_b418] trained on 160142 rows.
# [BATCH ep3_b419] packet/sparta shape=(200000, 31)
# [BATCH ep3_b419] trained on 159754 rows.
# [BATCH ep3_b420] packet/sparta shape=(200000, 31)
# [BATCH ep3_b420] trained on 160105 rows.
# [BATCH ep3_b421] packet/sparta shape=(200000, 31)
# [BATCH ep3_b421] trained on 159991 rows.
# [BATCH ep3_b422] packet/sparta shape=(200000, 31)
# [BATCH ep3_b422] trained on 159793 rows.
# [BATCH ep3_b423] packet/sparta shape=(200000, 31)
# [BATCH ep3_b423] trained on 160185 rows.
# [BATCH ep3_b424] packet/sparta shape=(200000, 31)
# [BATCH ep3_b424] trained on 160118 rows.
# [BATCH ep3_b425] packet/sparta shape=(200000, 31)
# [BATCH ep3_b425] trained on 159751 rows.
# [BATCH ep3_b426] packet/sparta shape=(200000, 31)
# [BATCH ep3_b426] trained on 160083 rows.
# [BATCH ep3_b427] packet/sparta shape=(200000, 31)
# [BATCH ep3_b427] trained on 159913 rows.
# [BATCH ep3_b428] packet/sparta shape=(200000, 31)
# [BATCH ep3_b428] trained on 159666 rows.
# [BATCH ep3_b429] packet/sparta shape=(200000, 31)
# [BATCH ep3_b429] trained on 159802 rows.
# [BATCH ep3_b430] packet/sparta shape=(200000, 31)
# [BATCH ep3_b430] trained on 160097 rows.
# [BATCH ep3_b431] packet/sparta shape=(200000, 31)
# [BATCH ep3_b431] trained on 159870 rows.
# [BATCH ep3_b432] packet/sparta shape=(200000, 31)
# [BATCH ep3_b432] trained on 159970 rows.
# [BATCH ep3_b433] packet/sparta shape=(200000, 31)
# [BATCH ep3_b433] trained on 160109 rows.
# [BATCH ep3_b434] packet/sparta shape=(200000, 31)
# [BATCH ep3_b434] trained on 159811 rows.
# [BATCH ep3_b435] packet/sparta shape=(200000, 31)
# [BATCH ep3_b435] trained on 160120 rows.
# [BATCH ep3_b436] packet/sparta shape=(200000, 31)
# [BATCH ep3_b436] trained on 159695 rows.
# [BATCH ep3_b437] packet/sparta shape=(200000, 31)
# [BATCH ep3_b437] trained on 159890 rows.
# [BATCH ep3_b438] packet/sparta shape=(200000, 31)
# [BATCH ep3_b438] trained on 159914 rows.
# [BATCH ep3_b439] packet/sparta shape=(200000, 31)
# [BATCH ep3_b439] trained on 160014 rows.
# [BATCH ep3_b440] packet/sparta shape=(200000, 31)
# [BATCH ep3_b440] trained on 160108 rows.
# [BATCH ep3_b441] packet/sparta shape=(200000, 31)
# [BATCH ep3_b441] trained on 159875 rows.
# [BATCH ep3_b442] packet/sparta shape=(200000, 31)
# [BATCH ep3_b442] trained on 159930 rows.
# [BATCH ep3_b443] packet/sparta shape=(200000, 31)
# [BATCH ep3_b443] trained on 160183 rows.
# [BATCH ep3_b444] packet/sparta shape=(200000, 31)
# [BATCH ep3_b444] trained on 160054 rows.
# [BATCH ep3_b445] packet/sparta shape=(200000, 31)
# [BATCH ep3_b445] trained on 160204 rows.
# [BATCH ep3_b446] packet/sparta shape=(200000, 31)
# [BATCH ep3_b446] trained on 160284 rows.
# [BATCH ep3_b447] packet/sparta shape=(200000, 31)
# [BATCH ep3_b447] trained on 160265 rows.
# [BATCH ep3_b448] packet/sparta shape=(200000, 31)
# [BATCH ep3_b448] trained on 159659 rows.
# [BATCH ep3_b449] packet/sparta shape=(200000, 31)
# [BATCH ep3_b449] trained on 159753 rows.
# [BATCH ep3_b450] packet/sparta shape=(200000, 31)
# [BATCH ep3_b450] trained on 159844 rows.
# [BATCH ep3_b451] packet/sparta shape=(200000, 31)
# [BATCH ep3_b451] trained on 160095 rows.
# [BATCH ep3_b452] packet/sparta shape=(200000, 31)
# [BATCH ep3_b452] trained on 160036 rows.
# [BATCH ep3_b453] packet/sparta shape=(200000, 31)
# [BATCH ep3_b453] trained on 160087 rows.
# [BATCH ep3_b454] packet/sparta shape=(200000, 31)
# [BATCH ep3_b454] trained on 159762 rows.
# [BATCH ep3_b455] packet/sparta shape=(200000, 31)
# [BATCH ep3_b455] trained on 160172 rows.
# [BATCH ep3_b456] packet/sparta shape=(200000, 31)
# [BATCH ep3_b456] trained on 160018 rows.
# [BATCH ep3_b457] packet/sparta shape=(200000, 31)
# [BATCH ep3_b457] trained on 160112 rows.
# [BATCH ep3_b458] packet/sparta shape=(76140, 31)
# [BATCH ep3_b458] trained on 60960 rows.
# [BATCH ep3_b459] packet/scan_A shape=(111392, 31)
# [BATCH ep3_b459] trained on 89219 rows.
# [BATCH ep3_b460] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b460] trained on 159972 rows.
# [BATCH ep3_b461] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b461] trained on 160083 rows.
# [BATCH ep3_b462] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b462] trained on 160137 rows.
# [BATCH ep3_b463] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b463] trained on 159822 rows.
# [BATCH ep3_b464] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b464] trained on 159757 rows.
# [BATCH ep3_b465] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b465] trained on 160106 rows.
# [BATCH ep3_b466] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b466] trained on 159865 rows.
# [BATCH ep3_b467] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b467] trained on 160162 rows.
# [BATCH ep3_b468] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b468] trained on 159925 rows.
# [BATCH ep3_b469] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b469] trained on 160174 rows.
# [BATCH ep3_b470] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b470] trained on 160071 rows.
# [BATCH ep3_b471] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b471] trained on 159883 rows.
# [BATCH ep3_b472] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b472] trained on 160516 rows.
# [BATCH ep3_b473] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b473] trained on 159984 rows.
# [BATCH ep3_b474] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b474] trained on 159844 rows.
# [BATCH ep3_b475] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b475] trained on 159725 rows.
# [BATCH ep3_b476] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b476] trained on 160138 rows.
# [BATCH ep3_b477] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b477] trained on 159799 rows.
# [BATCH ep3_b478] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b478] trained on 160189 rows.
# [BATCH ep3_b479] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b479] trained on 160223 rows.
# [BATCH ep3_b480] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b480] trained on 160224 rows.
# [BATCH ep3_b481] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b481] trained on 160234 rows.
# [BATCH ep3_b482] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b482] trained on 160182 rows.
# [BATCH ep3_b483] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b483] trained on 159904 rows.
# [BATCH ep3_b484] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b484] trained on 160003 rows.
# [BATCH ep3_b485] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b485] trained on 160152 rows.
# [BATCH ep3_b486] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b486] trained on 159668 rows.
# [BATCH ep3_b487] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b487] trained on 159979 rows.
# [BATCH ep3_b488] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b488] trained on 159941 rows.
# [BATCH ep3_b489] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b489] trained on 160201 rows.
# [BATCH ep3_b490] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b490] trained on 159887 rows.
# [BATCH ep3_b491] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b491] trained on 160062 rows.
# [BATCH ep3_b492] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b492] trained on 159980 rows.
# [BATCH ep3_b493] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b493] trained on 159909 rows.
# [BATCH ep3_b494] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b494] trained on 159997 rows.
# [BATCH ep3_b495] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b495] trained on 160041 rows.
# [BATCH ep3_b496] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b496] trained on 160023 rows.
# [BATCH ep3_b497] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b497] trained on 159971 rows.
# [BATCH ep3_b498] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b498] trained on 160180 rows.
# [BATCH ep3_b499] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b499] trained on 159822 rows.
# [BATCH ep3_b500] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b500] trained on 160027 rows.
# [BATCH ep3_b501] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b501] trained on 160338 rows.
# [BATCH ep3_b502] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b502] trained on 160016 rows.
# [BATCH ep3_b503] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b503] trained on 159891 rows.
# [BATCH ep3_b504] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b504] trained on 160110 rows.
# [BATCH ep3_b505] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b505] trained on 159910 rows.
# [BATCH ep3_b506] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b506] trained on 159992 rows.
# [BATCH ep3_b507] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b507] trained on 160280 rows.
# [BATCH ep3_b508] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b508] trained on 159937 rows.
# [BATCH ep3_b509] packet/mqtt_bruteforce shape=(200000, 31)
# [BATCH ep3_b509] trained on 160055 rows.
# [BATCH ep3_b510] packet/mqtt_bruteforce shape=(45316, 31)
# [BATCH ep3_b510] trained on 36209 rows.
# [BATCH ep3_b511] packet/scan_sU shape=(200000, 31)
# [BATCH ep3_b511] trained on 160146 rows.
# [BATCH ep3_b512] packet/scan_sU shape=(33255, 31)
# [BATCH ep3_b512] trained on 26686 rows.
# [BATCH ep3_b513] uniflow/normal shape=(171836, 19)
# ...
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDB324.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDB324.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDB325.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDB325.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDB921.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDB921.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDBAF7.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDBAF7.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC0E3.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC0E3.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC103.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC103.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC104.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC104.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC113.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC113.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC134.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC134.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC1E0.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC1E0.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC1E1.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC1E1.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC220.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC220.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC221.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC221.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC25F.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC25F.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC2ED.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC2ED.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC330.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC330.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC331.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC331.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC38A.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC38A.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC38B.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC38B.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC439.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC439.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC478.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC478.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC47B.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC47B.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC508.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC508.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC538.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC538.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC57F.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC57F.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC67A.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC67A.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC6D9.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC6D9.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC6EE.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC6EE.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC738.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC738.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC77C.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC77C.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC819.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC819.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC8F5.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC8F5.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC90E.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC90E.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDC9E3.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDC9E3.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCA32.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCA32.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCC12.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCC12.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCCF3.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCCF3.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCDC2.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCDC2.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCDD2.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCDD2.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCE12.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCE12.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCE32.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCE32.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCE33.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCE33.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDCE5C.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDCE5C.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD20D.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD20D.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD36F.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD36F.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD375.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD375.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD53B.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD53B.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD6A9.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD6A9.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD719.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD719.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD739.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD739.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD7B8.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD7B8.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD970.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD970.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDD972.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDD972.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDB18.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDB18.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDB58.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDB58.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDB59.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDB59.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDB97.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDB97.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDC15.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDC15.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDC83.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDC83.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDD10.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDD10.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDDDD.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDDDD.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDDF15.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDDF15.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE05F.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE05F.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0D0.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0D0.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0D1.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0D1.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0E3.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0E3.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0E4.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0E4.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0E5.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0E5.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0E6.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0E6.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE0F6.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE0F6.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE129.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE129.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE13A.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE13A.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE14A.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE14A.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE16C.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE16C.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE18D.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE18D.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE1AD.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE1AD.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE1E4.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE1E4.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDE744.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDE744.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDEBCB.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDEBCB.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFD1B.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFD1B.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFD1C.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFD1C.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFD1D.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFD1D.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFD9C.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFD9C.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFE2C.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFE2C.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFE3E.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFE3E.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFE4E.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFE4E.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFE7F.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFE7F.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFEA0.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFEA0.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFEB3.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFEB3.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFEB4.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFEB4.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFED8.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFED8.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFED9.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFED9.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFEDA.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFEDA.tmp'
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\TCDFEDB.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\TCDFEDB.tmp'
# [CLEANUP] Removed file: C:\Users\HP\AppData\Local\Temp\wct9F7D.tmp
# [CLEANUP] Removed file: C:\Users\HP\AppData\Local\Temp\wctFEDC.tmp
# [CLEANUP] Could not remove C:\Users\HP\AppData\Local\Temp\~nsu.tmp: [WinError 5] Access is denied: 'C:\\Users\\HP\\AppData\\Local\\Temp\\~nsu.tmp'
# [CLEANUP] Completed.
# c:\Users\HP\OneDrive - iiit-b\Desktop\Smart-Energy-and-Water-Management-Systems-PE\seawsenv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\HP\OneDrive - iiit-b\Desktop\Smart-Energy-and-Water-Management-Systems-PE\seawsenv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\HP\OneDrive - iiit-b\Desktop\Smart-Energy-and-Water-Management-Systems-PE\seawsenv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
