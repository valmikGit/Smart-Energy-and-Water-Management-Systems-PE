# %%
# cleanup_intermediate_files.py
# Standalone cleanup script to remove intermediate/temp files
# generated during SVM training. 
# Safe: leaves original raw dataset CSVs intact.

import os
import glob
import tempfile
import shutil

# ------------------------------
# Config
# ------------------------------
base_path = "./"
folders = {
    "packet": "packet_features",
    "uniflow": "uniflow_features",
    "biflow": "biflow_features"
}

# patterns considered "intermediate"
INTERMEDIATE_PATTERNS = [
    "*.tmp", "*.temp", "tmp*",
    "*.part", "*.cache", "*.bak",
    "*.npy", "*.npz"
]

# keep these (raw dataset files)
KEEP_FILES = {
    "normal.csv",
    "sparta.csv",
    "scan_A.csv",
    "mqtt_bruteforce.csv",
    "scan_sU.csv",
    "uniflow_normal.csv",
    "uniflow_sparta.csv",
    "uniflow_scan_A.csv",
    "uniflow_mqtt_bruteforce.csv",
    "uniflow_scan_sU.csv",
    "biflow_normal.csv",
    "biflow_sparta.csv",
    "biflow_scan_A.csv",
    "biflow_mqtt_bruteforce.csv",
    "biflow_scan_sU.csv",
}

# ------------------------------
# Helpers
# ------------------------------
def safe_remove(path):
    try:
        if os.path.exists(path):
            os.remove(path)
            print(f"[CLEANUP] Removed: {path}")
    except Exception as e:
        print(f"[CLEANUP] Could not remove {path}: {e}")

def cleanup_feature_folders():
    print("\n[STEP] Cleaning feature folders...")
    for level, folder in folders.items():
        fpath = os.path.join(base_path, folder)
        if not os.path.isdir(fpath):
            continue
        for pat in INTERMEDIATE_PATTERNS:
            for file in glob.glob(os.path.join(fpath, pat)):
                fname = os.path.basename(file)
                if fname in KEEP_FILES:
                    continue  # skip raw dataset files
                safe_remove(file)

def cleanup_tempdir():
    print("\n[STEP] Cleaning system temp directory...")
    tmpdir = tempfile.gettempdir()
    for pat in INTERMEDIATE_PATTERNS:
        for file in glob.glob(os.path.join(tmpdir, pat)):
            safe_remove(file)

def cleanup_misc():
    print("\n[STEP] Cleaning misc training artifacts...")
    # example: remove cached sklearn joblib models if present
    cache_dir = os.path.join(base_path, "__pycache__")
    if os.path.isdir(cache_dir):
        try:
            shutil.rmtree(cache_dir)
            print(f"[CLEANUP] Removed directory: {cache_dir}")
        except Exception as e:
            print(f"[CLEANUP] Could not remove {cache_dir}: {e}")

# ------------------------------
# Main
# ------------------------------
if __name__ == "__main__":
    print("[START CLEANUP SCRIPT]")
    cleanup_feature_folders()
    cleanup_tempdir()
    cleanup_misc()
    print("\n[CLEANUP] Completed successfully.")
# Out:
# [START CLEANUP SCRIPT]
#
# [STEP] Cleaning feature folders...
#
# [STEP] Cleaning system temp directory...
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\25e150fc-1947-4a6f-a4d7-e44453d6a15b.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\25e150fc-1947-4a6f-a4d7-e44453d6a15b.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\2a07e942-aff7-4960-9e6e-0343e024160d.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\2a07e942-aff7-4960-9e6e-0343e024160d.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\4d0981fe-0d47-479e-ab7c-d9f9258e1623.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\4d0981fe-0d47-479e-ab7c-d9f9258e1623.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\6b14c86a-937b-4b24-8c6b-d9a7a6bccb78.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\6b14c86a-937b-4b24-8c6b-d9a7a6bccb78.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\84a8e4b2-d2dd-459b-bbf9-365c055ccdec.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\84a8e4b2-d2dd-459b-bbf9-365c055ccdec.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\858b5f43-9f07-4c2a-a85d-1bdfd2fbbb52.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\858b5f43-9f07-4c2a-a85d-1bdfd2fbbb52.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\8c08ba2f-a81d-4dd2-9b32-30fad2e106c8.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\8c08ba2f-a81d-4dd2-9b32-30fad2e106c8.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\93a9ab28-744c-405c-af8d-e2698b8eb164.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\93a9ab28-744c-405c-af8d-e2698b8eb164.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\c30fae91-1f60-4331-a94d-88c40875a3a2.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\c30fae91-1f60-4331-a94d-88c40875a3a2.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\cd8e123f-f5ba-4186-b47f-7bf0f98d2077.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\cd8e123f-f5ba-4186-b47f-7bf0f98d2077.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\d2f66fff-d835-40ba-ae6a-dd07bf43b456.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\d2f66fff-d835-40ba-ae6a-dd07bf43b456.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\d87a3905-041f-449c-beb7-3b98c70d0b82.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\d87a3905-041f-449c-beb7-3b98c70d0b82.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\e0614541-4a4c-48fb-adc7-f04bc62bbc07.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\e0614541-4a4c-48fb-adc7-f04bc62bbc07.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\e70e6313-8b6d-4995-8da4-46b58bce1b4e.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\e70e6313-8b6d-4995-8da4-46b58bce1b4e.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\ed16c754-568b-43ca-9fcb-95515b10ffb9.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\ed16c754-568b-43ca-9fcb-95515b10ffb9.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\f5624ea0-8020-44bd-a923-07bde22d2f74.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\f5624ea0-8020-44bd-a923-07bde22d2f74.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\~nsu1.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\~nsu1.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\~nsu2.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\~nsu2.tmp'
#
# [STEP] Cleaning misc training artifacts...
#
# [CLEANUP] Completed successfully.
