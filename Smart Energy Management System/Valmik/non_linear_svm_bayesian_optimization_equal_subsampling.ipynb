# %%
import os
import glob
import time
import tempfile
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.model_selection import GridSearchCV
import random

# Try to import BayesSearchCV from scikit-optimize
use_bayes = False
try:
    from skopt import BayesSearchCV
    from skopt.space import Real, Categorical
    use_bayes = True
    print("[INFO] scikit-optimize detected: using BayesSearchCV (GP surrogate).")
except Exception:
    print("[WARN] scikit-optimize not available. Falling back to GridSearchCV (grid search).")

# ------------------------------
# Config
# ------------------------------
base_path = "./"

folders = {
    "packet": "packet_features",
    "uniflow": "uniflow_features",
    "biflow": "biflow_features"
}

files = {
    "normal": "normal.csv",
    "sparta": "sparta.csv",
    "scan_A": "scan_A.csv",
    "mqtt_bruteforce": "mqtt_bruteforce.csv",
    "scan_sU": "scan_sU.csv"
}

def build_filenames(prefix):
    return {
        "normal": f"{prefix}_normal.csv",
        "sparta": f"{prefix}_sparta.csv",
        "scan_A": f"{prefix}_scan_A.csv",
        "mqtt_bruteforce": f"{prefix}_mqtt_bruteforce.csv",
        "scan_sU": f"{prefix}_scan_sU.csv"
    }

feature_files = {
    "packet": files,
    "uniflow": build_filenames("uniflow"),
    "biflow": build_filenames("biflow")
}

CHUNKSIZE = 200000
TRAIN_FRACTION = 0.80
VAL_FRACTION = 0.10
TEST_FRACTION = 0.10

EPOCHS = 3
SAMPLE_VAL_MAX = 20000
SAMPLE_TEST_MAX = 20000
MAX_TRAIN_SAMPLES = 200   # 🔹 Balanced: 100 per class if 2 classes

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.seed(RANDOM_SEED)

BAYES_N_ITER = 25
CV_FOLDS = 3
SCORING = "f1_macro"

GRID_PARAM_GRID = {
    "C": [0.1, 1, 10],
    "gamma": ["scale", 0.01, 0.001],
    "kernel": ["rbf"]
}

# ------------------------------
# Helpers
# ------------------------------
def safe_remove(path):
    try:
        if os.path.exists(path):
            os.remove(path)
            print(f"[CLEANUP] Removed file: {path}")
    except Exception as e:
        print(f"[CLEANUP] Could not remove {path}: {e}")

def stream_chunks(feature_files_map, base_path, chunksize=CHUNKSIZE):
    for level, file_dict in feature_files_map.items():
        folder_path = os.path.join(base_path, folders[level])
        for key, fname in file_dict.items():
            fpath = os.path.join(folder_path, fname)
            if not os.path.isfile(fpath):
                print(f"[WARN] Missing: {fpath}")
                continue
            try:
                for chunk in pd.read_csv(fpath, chunksize=chunksize, low_memory=False):
                    yield (level, key, fpath, chunk)
            except Exception as e:
                print(f"[ERROR] Failed to read {fpath}: {e}")

def preprocess_chunk(df, file_key, expected_features=None):
    df = df.copy()
    df["attack"] = (file_key != "normal")
    y = df["attack"].astype(int).values
    numeric_df = df.select_dtypes(include=[np.number]).copy()
    if "attack" in numeric_df.columns:
        numeric_df = numeric_df.drop(columns=["attack"])
    if "label" in numeric_df.columns:
        numeric_df = numeric_df.drop(columns=["label"])
    if expected_features is not None:
        numeric_df = numeric_df.reindex(columns=expected_features, fill_value=0.0)
        feature_names = expected_features
    else:
        feature_names = list(numeric_df.columns)
    if len(feature_names) == 0:
        X = np.zeros((numeric_df.shape[0], 0), dtype=np.float32)
    else:
        X = numeric_df.fillna(0.0).values.astype(np.float32)
    return X, y, feature_names

# ------------------------------
# Training loop
# ------------------------------
def train_svm_rbf_bayes(feature_files_map, base_path, epochs=EPOCHS):
    scaler = StandardScaler(with_mean=False)
    feature_names_master = None
    val_X = None; val_y = None
    test_X = None; test_y = None
    best_model = None
    best_params_overall = None

    for epoch in range(1, epochs + 1):
        print(f"\n=== EPOCH {epoch}/{epochs} ===")
        train_chunks_X = []
        train_chunks_y = []

        for level, file_key, filepath, chunk in stream_chunks(feature_files_map, base_path):
            print(f"[EPOCH {epoch}] CHUNK {level}/{file_key} shape={chunk.shape}")
            try:
                if feature_names_master is None:
                    Xc, yc, feat_names = preprocess_chunk(chunk, file_key, expected_features=None)
                    feature_names_master = feat_names
                    print(f"[INFO] Established master feature count: {len(feature_names_master)}")
                else:
                    Xc, yc, _ = preprocess_chunk(chunk, file_key, expected_features=feature_names_master)
            except Exception as e:
                print(f"[SKIP] Preprocess error: {e}")
                continue
            if Xc.shape[1] == 0 or Xc.shape[0] == 0:
                continue

            n = Xc.shape[0]
            rnd = np.random.rand(n)
            train_mask = rnd < TRAIN_FRACTION
            val_mask = (rnd >= TRAIN_FRACTION) & (rnd < TRAIN_FRACTION + VAL_FRACTION)
            test_mask = rnd >= TRAIN_FRACTION + VAL_FRACTION

            X_train_chunk = Xc[train_mask]; y_train_chunk = yc[train_mask]
            X_val_chunk = Xc[val_mask]; y_val_chunk = yc[val_mask]
            X_test_chunk = Xc[test_mask]; y_test_chunk = yc[test_mask]

            if X_train_chunk.shape[0] > 0:
                train_chunks_X.append(X_train_chunk)
                train_chunks_y.append(y_train_chunk)

            if X_val_chunk.shape[0] > 0:
                if val_X is None:
                    take = min(X_val_chunk.shape[0], SAMPLE_VAL_MAX)
                    idxs = np.random.choice(X_val_chunk.shape[0], take, replace=False)
                    val_X = X_val_chunk[idxs]; val_y = y_val_chunk[idxs]
                else:
                    val_X = np.vstack([val_X, X_val_chunk])
                    val_y = np.concatenate([val_y, y_val_chunk])
                    if val_X.shape[0] > SAMPLE_VAL_MAX:
                        idxs = np.random.choice(val_X.shape[0], SAMPLE_VAL_MAX, replace=False)
                        val_X = val_X[idxs]; val_y = val_y[idxs]

            if X_test_chunk.shape[0] > 0:
                if test_X is None:
                    take = min(X_test_chunk.shape[0], SAMPLE_TEST_MAX)
                    idxs = np.random.choice(X_test_chunk.shape[0], take, replace=False)
                    test_X = X_test_chunk[idxs]; test_y = y_test_chunk[idxs]
                else:
                    test_X = np.vstack([test_X, X_test_chunk])
                    test_y = np.concatenate([test_y, y_test_chunk])
                    if test_X.shape[0] > SAMPLE_TEST_MAX:
                        idxs = np.random.choice(test_X.shape[0], SAMPLE_TEST_MAX, replace=False)
                        test_X = test_X[idxs]; test_y = test_y[idxs]

        if len(train_chunks_X) == 0:
            print("[WARN] No training data collected this epoch; skipping.")
            continue

        X_train = np.vstack(train_chunks_X)
        y_train = np.concatenate(train_chunks_y)

        # 🔹 Balanced subsampling
        if X_train.shape[0] > MAX_TRAIN_SAMPLES:
            class0_idx = np.where(y_train == 0)[0]
            class1_idx = np.where(y_train == 1)[0]
            n_per_class = MAX_TRAIN_SAMPLES // 2
            if len(class0_idx) < n_per_class or len(class1_idx) < n_per_class:
                min_class = min(len(class0_idx), len(class1_idx))
                n_per_class = min_class
                print(f"[WARN] Not enough samples in one class; using {n_per_class} per class.")
            sel0 = np.random.choice(class0_idx, n_per_class, replace=False)
            sel1 = np.random.choice(class1_idx, n_per_class, replace=False)
            sel_idx = np.concatenate([sel0, sel1])
            X_train = X_train[sel_idx]
            y_train = y_train[sel_idx]
            print(f"[INFO] Downsampled balanced training set to {X_train.shape[0]} samples "
                  f"({n_per_class} per class).")

        X_train = scaler.fit_transform(X_train)
        if val_X is not None:
            val_X_scaled = scaler.transform(val_X)
        else:
            val_X_scaled = None
        if test_X is not None:
            test_X_scaled = scaler.transform(test_X)
        else:
            test_X_scaled = None

        if use_bayes:
            search_spaces = {
                "C": Real(1e-3, 1e3, prior="log-uniform"),
                "gamma": Real(1e-4, 1e1, prior="log-uniform"),
                "kernel": Categorical(["rbf"])
            }
            bayes = BayesSearchCV(
                estimator=SVC(),
                search_spaces=search_spaces,
                n_iter=BAYES_N_ITER,
                scoring=SCORING,
                cv=CV_FOLDS,
                n_jobs=-1,
                verbose=0,
                random_state=RANDOM_SEED,
                optimizer_kwargs={"acq_func": "EI"}
            )
            print(f"[EPOCH {epoch}] Running BayesSearchCV ...")
            bayes.fit(X_train, y_train)
            best_est = bayes.best_estimator_
            best_params = bayes.best_params_
            best_score = bayes.best_score_
            print(f"[EPOCH {epoch}] Bayes best params: {best_params}  CV {SCORING}={best_score:.4f}")
            best_model = best_est
            best_params_overall = best_params
        else:
            print(f"[EPOCH {epoch}] Running GridSearchCV fallback.")
            grid = GridSearchCV(SVC(), GRID_PARAM_GRID, cv=CV_FOLDS, scoring=SCORING, n_jobs=-1, verbose=1)
            grid.fit(X_train, y_train)
            best_model = grid.best_estimator_
            best_params_overall = grid.best_params_
            print(f"[EPOCH {epoch}] Grid best params: {best_params_overall}  CV {SCORING}={grid.best_score_:.4f}")

        try:
            best_model.fit(X_train, y_train)
        except Exception as e:
            print(f"[WARN] best_model.fit failed: {e}")

        if val_X_scaled is not None:
            preds_val = best_model.predict(val_X_scaled)
            acc_val = accuracy_score(val_y, preds_val)
            f1_val = f1_score(val_y, preds_val, average="macro")
            print(f"[EPOCH {epoch}] Validation: Acc={acc_val:.4f}  F1={f1_val:.4f}")
        if test_X_scaled is not None:
            preds_test = best_model.predict(test_X_scaled)
            acc_test = accuracy_score(test_y, preds_test)
            f1_test = f1_score(test_y, preds_test, average="macro")
            print(f"[EPOCH {epoch}] Test: Acc={acc_test:.4f}  F1={f1_test:.4f}")

        best_model_epoch = best_model

    final_model = best_model_epoch if 'best_model_epoch' in locals() else None
    if final_model is not None and test_X is not None:
        preds = final_model.predict(test_X_scaled)
        acc = accuracy_score(test_y, preds)
        f1 = f1_score(test_y, preds, average="macro")
        print("\n=== FINAL TEST METRICS ===")
        print(f"Test Acc={acc:.4f}  F1_macro={f1:.4f}")
        print(classification_report(test_y, preds, target_names=["Secure(False)", "Attack(True)"]))
    else:
        print("No final model or test pool to evaluate.")
    return final_model, feature_names_master, best_params_overall

# ------------------------------
# Main
# ------------------------------
if __name__ == "__main__":
    start_time = time.time()
    print(f"[START] Training RBF SVM with per-epoch Bayesian optimization (epochs={EPOCHS})...")
    try:
        svm_model, features, best_params = train_svm_rbf_bayes(feature_files, base_path, epochs=EPOCHS)
    except Exception as e:
        print(f"[FATAL] Training aborted: {e}")
        svm_model, features, best_params = None, None, None
    elapsed = time.time() - start_time
    print(f"[DONE] Total time: {elapsed:.1f}s")
    if best_params is not None:
        print(f"[RESULT] Best params (last epoch): {best_params}")
    print("\n[START CLEANUP]")
    tmpdir = tempfile.gettempdir()
    for pattern in ["*.tmp", "*.temp", "tmp*"]:
        for f in glob.glob(os.path.join(tmpdir, pattern)):
            safe_remove(f)
    print("[CLEANUP] Completed.")
# Out:
# [INFO] scikit-optimize detected: using BayesSearchCV (GP surrogate).
# [START] Training RBF SVM with per-epoch Bayesian optimization (epochs=3)...
#
# === EPOCH 1/3 ===
# [EPOCH 1] CHUNK packet/normal shape=(200000, 31)
# [INFO] Established master feature count: 27
# [EPOCH 1] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 1] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 1] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 1] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 1] CHUNK packet/normal shape=(56231, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 1] CHUNK packet/sparta shape=(76140, 31)
# [EPOCH 1] CHUNK packet/scan_A shape=(111392, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 1] CHUNK packet/mqtt_bruteforce shape=(45316, 31)
# [EPOCH 1] CHUNK packet/scan_sU shape=(200000, 31)
# [EPOCH 1] CHUNK packet/scan_sU shape=(33255, 31)
# [EPOCH 1] CHUNK uniflow/normal shape=(171836, 19)
# [EPOCH 1] CHUNK uniflow/sparta shape=(182407, 19)
# [EPOCH 1] CHUNK uniflow/scan_A shape=(51358, 19)
# [EPOCH 1] CHUNK uniflow/mqtt_bruteforce shape=(33079, 19)
# [EPOCH 1] CHUNK uniflow/scan_sU shape=(56845, 19)
# [EPOCH 1] CHUNK biflow/normal shape=(86008, 32)
# [EPOCH 1] CHUNK biflow/sparta shape=(91318, 32)
# [EPOCH 1] CHUNK biflow/scan_A shape=(25693, 32)
# [EPOCH 1] CHUNK biflow/mqtt_bruteforce shape=(16696, 32)
# [EPOCH 1] CHUNK biflow/scan_sU shape=(39664, 32)
# [INFO] Downsampled balanced training set to 200 samples (100 per class).
# [EPOCH 1] Running BayesSearchCV ...
# [EPOCH 1] Bayes best params: OrderedDict({'C': 74.88174047459994, 'gamma': 0.0007233655252968397, 'kernel': 'rbf'})  CV f1_macro=0.8350
# [EPOCH 1] Validation: Acc=0.7920  F1=0.4419
# [EPOCH 1] Test: Acc=0.7913  F1=0.4417
#
# === EPOCH 2/3 ===
# [EPOCH 2] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 2] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 2] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 2] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 2] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 2] CHUNK packet/normal shape=(56231, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 2] CHUNK packet/sparta shape=(76140, 31)
# [EPOCH 2] CHUNK packet/scan_A shape=(111392, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 2] CHUNK packet/mqtt_bruteforce shape=(45316, 31)
# [EPOCH 2] CHUNK packet/scan_sU shape=(200000, 31)
# [EPOCH 2] CHUNK packet/scan_sU shape=(33255, 31)
# [EPOCH 2] CHUNK uniflow/normal shape=(171836, 19)
# [EPOCH 2] CHUNK uniflow/sparta shape=(182407, 19)
# [EPOCH 2] CHUNK uniflow/scan_A shape=(51358, 19)
# [EPOCH 2] CHUNK uniflow/mqtt_bruteforce shape=(33079, 19)
# [EPOCH 2] CHUNK uniflow/scan_sU shape=(56845, 19)
# [EPOCH 2] CHUNK biflow/normal shape=(86008, 32)
# [EPOCH 2] CHUNK biflow/sparta shape=(91318, 32)
# [EPOCH 2] CHUNK biflow/scan_A shape=(25693, 32)
# [EPOCH 2] CHUNK biflow/mqtt_bruteforce shape=(16696, 32)
# [EPOCH 2] CHUNK biflow/scan_sU shape=(39664, 32)
# [INFO] Downsampled balanced training set to 200 samples (100 per class).
# [EPOCH 2] Running BayesSearchCV ...
# [EPOCH 2] Bayes best params: OrderedDict({'C': 94.71135745457283, 'gamma': 0.00014248831979729102, 'kernel': 'rbf'})  CV f1_macro=0.8881
# [EPOCH 2] Validation: Acc=0.5609  F1=0.5451
# [EPOCH 2] Test: Acc=0.5546  F1=0.5358
#
# === EPOCH 3/3 ===
# [EPOCH 3] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 3] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 3] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 3] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 3] CHUNK packet/normal shape=(200000, 31)
# [EPOCH 3] CHUNK packet/normal shape=(56231, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(200000, 31)
# [EPOCH 3] CHUNK packet/sparta shape=(76140, 31)
# [EPOCH 3] CHUNK packet/scan_A shape=(111392, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(200000, 31)
# [EPOCH 3] CHUNK packet/mqtt_bruteforce shape=(45316, 31)
# [EPOCH 3] CHUNK packet/scan_sU shape=(200000, 31)
# [EPOCH 3] CHUNK packet/scan_sU shape=(33255, 31)
# [EPOCH 3] CHUNK uniflow/normal shape=(171836, 19)
# [EPOCH 3] CHUNK uniflow/sparta shape=(182407, 19)
# [EPOCH 3] CHUNK uniflow/scan_A shape=(51358, 19)
# [EPOCH 3] CHUNK uniflow/mqtt_bruteforce shape=(33079, 19)
# [EPOCH 3] CHUNK uniflow/scan_sU shape=(56845, 19)
# [EPOCH 3] CHUNK biflow/normal shape=(86008, 32)
# [EPOCH 3] CHUNK biflow/sparta shape=(91318, 32)
# [EPOCH 3] CHUNK biflow/scan_A shape=(25693, 32)
# [EPOCH 3] CHUNK biflow/mqtt_bruteforce shape=(16696, 32)
# [EPOCH 3] CHUNK biflow/scan_sU shape=(39664, 32)
# [INFO] Downsampled balanced training set to 200 samples (100 per class).
# [EPOCH 3] Running BayesSearchCV ...
# [EPOCH 3] Bayes best params: OrderedDict({'C': 74.88174047459994, 'gamma': 0.0007233655252968397, 'kernel': 'rbf'})  CV f1_macro=0.8990
# [EPOCH 3] Validation: Acc=0.5594  F1=0.5408
# [EPOCH 3] Test: Acc=0.5674  F1=0.5510
#
# === FINAL TEST METRICS ===
# Test Acc=0.5674  F1_macro=0.5510
#                precision    recall  f1-score   support
#
# Secure(False)       0.30      1.00      0.47      3763
#  Attack(True)       1.00      0.47      0.64     16237
#
#      accuracy                           0.57     20000
#     macro avg       0.65      0.73      0.55     20000
#  weighted avg       0.87      0.57      0.60     20000
#
# [DONE] Total time: 366.6s
# [RESULT] Best params (last epoch): OrderedDict({'C': 74.88174047459994, 'gamma': 0.0007233655252968397, 'kernel': 'rbf'})
#
# [START CLEANUP]
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\1005fb74-ed1e-4f26-8251-f7c3855afcc0.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\1005fb74-ed1e-4f26-8251-f7c3855afcc0.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\19dedee1-4ff0-49f3-b71b-596ce0fe84b0.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\19dedee1-4ff0-49f3-b71b-596ce0fe84b0.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\1ed819cd-d1f3-4fe7-a435-9e416fa49d8e.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\1ed819cd-d1f3-4fe7-a435-9e416fa49d8e.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\23223399-8ef9-48c9-9f96-e8c6fdcb7413.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\23223399-8ef9-48c9-9f96-e8c6fdcb7413.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\24305aae-bc85-40a3-aeb5-a868732de4ae.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\24305aae-bc85-40a3-aeb5-a868732de4ae.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\29dd70a8-b60a-4640-a273-c5c3ec49aee0.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\29dd70a8-b60a-4640-a273-c5c3ec49aee0.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\322ff292-40c3-4e32-9a0f-c706f469882e.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\322ff292-40c3-4e32-9a0f-c706f469882e.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\42fd85d1-297d-4166-be2f-ed4bbc647145.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\42fd85d1-297d-4166-be2f-ed4bbc647145.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\5af0bc70-7414-43ae-89f2-41f370c6fa09.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\5af0bc70-7414-43ae-89f2-41f370c6fa09.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\85587f77-3c32-427d-afdb-e26ad9535062.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\85587f77-3c32-427d-afdb-e26ad9535062.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\8797e819-1717-446d-a395-e2e17dd31b3b.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\8797e819-1717-446d-a395-e2e17dd31b3b.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\97e4a03b-1c48-481e-9ef8-72c45ae60262.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\97e4a03b-1c48-481e-9ef8-72c45ae60262.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\99025b61-0ab4-46ca-9f8b-f685a5fc8ed8.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\99025b61-0ab4-46ca-9f8b-f685a5fc8ed8.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\a407f844-2805-413e-9645-4d35420d5711.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\a407f844-2805-413e-9645-4d35420d5711.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\b1c6f6c3-b37f-426c-8baa-6cd603c234b7.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\b1c6f6c3-b37f-426c-8baa-6cd603c234b7.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\ceb9882f-3982-4e57-ad8e-c7bf58c48b73.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\ceb9882f-3982-4e57-ad8e-c7bf58c48b73.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\dc4f0cc8-87f0-4685-9e10-df069846e269.tmp: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\dc4f0cc8-87f0-4685-9e10-df069846e269.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD5613.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD5613.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD5682.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD5682.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD578E.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD578E.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD57FD.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD57FD.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD58CA.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD58CA.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD5AEF.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD5AEF.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD5BAD.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD5BAD.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD5EBD.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD5EBD.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD5ECE.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD5ECE.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD6095.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD6095.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCD6327.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCD6327.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE08A.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE08A.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE08B.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE08B.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE08C.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE08C.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE08E.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE08E.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE0A2.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE0A2.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE0A3.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE0A3.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE0B4.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE0B4.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE0D5.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE0D5.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE0E6.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE0E6.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE174.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE174.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE195.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE195.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE32F.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE32F.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDE34F.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDE34F.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB33.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB33.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB43.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB43.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB44.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB44.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB4D.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB4D.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB5E.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB5E.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB5F.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB5F.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB6F.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB6F.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB70.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB70.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB81.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB81.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB82.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB82.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEB93.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEB93.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEBA3.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEBA3.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\TCDEBB5.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\TCDEBB5.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\~nsu1.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\~nsu1.tmp'
# [CLEANUP] Could not remove C:\Users\VALMIK~1\AppData\Local\Temp\~nsu2.tmp: [WinError 5] Access is denied: 'C:\\Users\\VALMIK~1\\AppData\\Local\\Temp\\~nsu2.tmp'
# [CLEANUP] Completed.
